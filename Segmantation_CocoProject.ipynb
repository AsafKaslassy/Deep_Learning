# %%
# %matplotlib inline
import os
from glob import glob
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
from tensorflow.keras.models import Model, model_from_json
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Flatten, Dense, concatenate

from tensorflow.keras.layers import Softmax
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers
from sklearn.metrics import confusion_matrix
from plot_confusion_matrix import plot_confusion_matrix

import cv2
pylab.rcParams['figure.figsize'] = (8.0, 10.0)

# %%
def read_data(directory):
# =============================================================================
#  This function gets a directory name and returns all images in it concatenated 
#  to each other
# =============================================================================    
    data_list = glob(os.path.join(directory ,r'*.png'))
    #print(os.path.join(directory,'*.png'))
    data = np.asarray([cv2.imread(img,0) for img in data_list])
    return data

# %%
# display COCO categories and supercategories
# cats = coco.loadCats(coco.getCatIds())
# nms=[cat['name'] for cat in cats]
# print('COCO categories: \n{}\n'.format(' '.join(nms)))

# nms = set([cat['supercategory'] for cat in cats])
# print('COCO supercategories: \n{}'.format(' '.join(nms)))

# %%
# the index of the image from the set just to visualize 
img_idx = 0

dataDir = "E:\Documents\Study\Deep Learning\Project\DATA"
train_data_name = "train2017"
val_data_name = "val2017"

# we resize the images because of memory limitations on my 32GB RAM and 4GB GPU memory
img_width = 64
img_height = 64

# size of the data set for debug {None => all the data} 
max_cnt_debug_train = None
max_cnt_debug_test = 10

# load images in grayscale or in RGB when rgb_on = 1 it will load rgb images
rgb_on = 1

# parameters for the training model number of classes will be autometicly generated based on the number of categories
lr =          1e-4        # learning rate 
beta_1 =      0.9         # beta 1 - for adam optimizer
beta_2 =      0.95        # beta 2 - for adam optimizer
epsilon =     1e-7        # epsilon - for adam optimizer
epochs =      50          # number of epochs
bs =          32          # batch size
dp =          0.5         # dropout probability


# in the .getCatIds(catNms=[list of all ids we want to filter from the data]);
categories_names = ['person']

# %%
# load captions
#coco_caps= COCO(os.path.join(dataDir,r"annotations\captions_" + data_name + ".json"))

# Load insatnces -> here we take the masks
coco_instances = COCO(os.path.join(dataDir,r"annotations\instances_" + train_data_name + ".json"))

# Load key points
#coco_key_p = COCO(os.path.join(dataDir,r"annotations\person_keypoints_" + data_name + ".json")) 

# get the id for each category specified
catIds = coco_instances.getCatIds(catNms=categories_names);

#get all image id in the directory
all_imgIds = coco_instances.getImgIds()

# get all the image id for all images based on the filter
imgIds = coco_instances.getImgIds(catIds=catIds);

# get the data for each image id with specified annotations
img_data = coco_instances.loadImgs(imgIds)

# Visualize the img_idx specified up here
I = io.imread(os.path.join(dataDir, train_data_name +r"//" +str(imgIds[img_idx]).zfill(12) + ".jpg"))
plt.imshow(I); 
plt.axis('off')
plt.title("image id: " + str(imgIds[img_idx]))

# and show the mask on top of the image
annIds = coco_instances.getAnnIds(imgIds=imgIds[img_idx], catIds=catIds, iscrowd=None)
anns = coco_instances.loadAnns(annIds)
coco_instances.showAnns(anns)

#plot key points
#annIds_keys = coco_key_p.getAnnIds(imgIds=imgIds[idx], catIds=catIds, iscrowd=None)
#anns_keys = coco_key_p.loadAnns(annIds_keys)
#coco_key_p.showAnns(anns_keys)

#print the caption
#annIds = coco_caps.getAnnIds(imgIds=imgIds[idx]);
#anns = coco_caps.loadAnns(annIds)
#coco_caps.showAnns(anns)
# Out:
# loading annotations into memory...
# Done (t=12.68s)
# creating index...
# index created!

# %%
#visualize the mask of the annotaion
# every annotation has a id (number) for every pixel on the mask we multiply by id
# pixel = id = we have annotation in the pixel
# pixel = 0 we dont have annotation in that spot
anns_img = np.zeros((img_data[img_idx]['height'],img_data[img_idx]['width']))
for ann in anns:
    #mask += coco_instances.annToMask(anns[i])*anns[i]['category_id'] 
    anns_img = np.maximum(anns_img, coco_instances.annToMask(ann)*ann['category_id'])
    
plt.subplot(2,1,1)    
plt.imshow(anns_img)
plt.axis('off')
plt.subplot(2,1,2)
# Visuaslize the histogram of the mask
plt.hist(anns_img.ravel(),256, [0,50]);

# %%
mask_list = [] # init empty list for masks

# we load all the images in grayscale because of memory limitations
img_list = [] # init empty list to store all the image data

for cnt, imgID in enumerate(all_imgIds):
    I = cv2.imread(os.path.join(dataDir, train_data_name +r"//" +str(imgID).zfill(12) + ".jpg"), rgb_on)
    I = cv2.resize(I, dsize=(img_width, img_height), interpolation=cv2.INTER_CUBIC)
    img_list.append(I)
    
    if (imgID in imgIds):
        # get all annotation ids for img id
        annIds = coco_instances.getAnnIds(imgIds=imgID, catIds=catIds, iscrowd=None) 
        # load all annotation inside the image
        anns = coco_instances.loadAnns(annIds) 
        # image data for image specification width height etc..
        #img_data = coco_instances.loadImgs(imgID)[0] 
    
        # init empty mask
        anns_img = np.zeros((img_height, img_width),) 
        for ann in anns:
            # resize the mask of the  specific anotation in the image
            mask_res = cv2.resize(coco_instances.annToMask(ann), (img_height, img_width), interpolation = cv2.INTER_AREA )
            # add the mask multiplid by the category index for category 
            # here we multiply by the index of the annotation +1
            # for easier way to_categories
            # if we have only one category it will be mask of only zeros ans ones
            # if we would multiply by the category id the to_category will make more categories then we need
            # for example if the category is 17 it will generate 18 categories and we need only 2
            anns_img = np.maximum(anns_img, mask_res*(catIds.index(ann['category_id'])+1))
    else:
        anns_img = np.zeros((img_height, img_width),)
    # for debug save the mask to the disk
    #cv2.imwrite(r"E:\Documents\Study\Deep Learning\Project\MASKS\\" +str(imgID).zfill(12) + ".png" , anns_img)
    mask_list.append(anns_img)
    
    if (cnt+1 == max_cnt_debug_train):
        break

# read the masks from the disk
#y_train = read_data(r'E:\Documents\Study\Deep Learning\Project\MASKS')
#y_train = (to_categorical(y_train)).astype('float')

y_train = np.asarray(mask_list)
y_train = (to_categorical(y_train, num_classes=None, dtype='float32')).astype('float')

x_train = np.asarray(img_list)
if (rgb_on == 0):
    x_train = (np.expand_dims(x_train, axis=3)).astype('float')

print('y_train shape:', y_train.shape)
print('x_train shape:', x_train.shape)
# Out:
# y_train shape: (118287, 64, 64, 2)
# x_train shape: (118287, 64, 64, 3)

# %%
#visualize the first image from the set
I = io.imread(os.path.join(dataDir, train_data_name +r"//" +str(imgIds[0]).zfill(12) + ".jpg"))
#I = cv2.cvtColor(I, cv2.COLOR_RGB2BGR)

#Visualize the image
plt.subplot(2,1,1)    
plt.imshow(I)
plt.axis('off')
#visualize the histogram of the image
plt.subplot(2,1,2)   
plt.hist(I.ravel(),256, [0,255]);

# %%
# number of classes for prediction based on the to_categorial
num_of_clss = y_train.shape[3]  # number of classes (the number of the categories form the to_categorial by keras)

# %%
inp = Input(shape = (x_train.shape[1],x_train.shape[2],x_train.shape[3]))

# First conv block
# x = Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(inp)
# x = Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
# x = BatchNormalization()(x)
# x = MaxPooling2D((2, 2))(x)

# Second conv block
x = Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(inp)
x = Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(dp)(x)
# Third conv block
x = Conv2D(32, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = Conv2D(32, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

# forth conv block
x = Conv2D(16, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = Conv2D(16, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = Conv2D(16, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(dp)(x)
# DECONV AND UNPOOLING

x = Conv2DTranspose(16, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2DTranspose(32, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2DTranspose(64, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = UpSampling2D((2, 2))(x)

# x = Conv2DTranspose(128, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
# x = UpSampling2D((2, 2))(x)

out = Conv2DTranspose(num_of_clss, (3, 3), strides=(1, 1), padding='same', activation = 'softmax')(x)

model = Model(inp,out)

# %%
# define the optimizer and compile the model
adam = optimizers.Adam(lr=lr, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, validation_split=0.3, epochs=epochs, batch_size=bs)
# Out:
# Train on 82800 samples, validate on 35487 samples
# Epoch 1/50
# 82800/82800 [==============================] - 173s 2ms/sample - loss: 0.2569 - accuracy: 0.9089 - val_loss: 0.2457 - val_accuracy: 0.9142
# Epoch 2/50
# 82800/82800 [==============================] - 167s 2ms/sample - loss: 0.2259 - accuracy: 0.9140 - val_loss: 0.2335 - val_accuracy: 0.9169
# Epoch 3/50
# 82800/82800 [==============================] - 167s 2ms/sample - loss: 0.2154 - accuracy: 0.9174 - val_loss: 0.2151 - val_accuracy: 0.9208
# Epoch 4/50
# 82800/82800 [==============================] - 167s 2ms/sample - loss: 0.2085 - accuracy: 0.9194 - val_loss: 0.2000 - val_accuracy: 0.9228
# Epoch 5/50
# 82800/82800 [==============================] - 167s 2ms/sample - loss: 0.2030 - accuracy: 0.9214 - val_loss: 0.2165 - val_accuracy: 0.9230
# Epoch 6/50
# 82800/82800 [==============================] - 167s 2ms/sample - loss: 0.1981 - accuracy: 0.9230 - val_loss: 0.1875 - val_accuracy: 0.9286
# Epoch 7/50
# 82800/82800 [==============================] - 167s 2ms/sample - loss: 0.1945 - accuracy: 0.9243 - val_loss: 0.1955 - val_accuracy: 0.9260
# Epoch 8/50
# 82800/82800 [==============================] - 167s 2ms/sample - loss: 0.1918 - accuracy: 0.9251 - val_loss: 0.1922 - val_accuracy: 0.9265
# Epoch 9/50
# 82800/82800 [==============================] - 166s 2ms/sample - loss: 0.1890 - accuracy: 0.9263 - val_loss: 0.1831 - val_accuracy: 0.9293
# Epoch 10/50
# 82800/82800 [==============================] - 167s 2ms/sample - loss: 0.1868 - accuracy: 0.9271 - val_loss: 0.1786 - val_accuracy: 0.9300
# Epoch 11/50
# 82800/82800 [==============================] - 167s 2ms/sample - loss: 0.1843 - accuracy: 0.9280 - val_loss: 0.1851 - val_accuracy: 0.9305
# Epoch 12/50
# 82800/82800 [==============================] - 167s 2ms/sample - loss: 0.1824 - accuracy: 0.9287 - val_loss: 0.1807 - val_accuracy: 0.9328
# Epoch 13/50
# 82800/82800 [==============================] - 152s 2ms/sample - loss: 0.1808 - accuracy: 0.9296 - val_loss: 0.1756 - val_accuracy: 0.9319oss: 0.1798 - accuracy: 0.929 - ETA: 59s - loss: 0.1798 - accu - ETA: 58s - loss: 0.1801  - ETA: 56s - loss: 0 - ETA: 54s - loss: 0.1799 - accura - ETA: 53s - loss: 0.1800 - accuracy: 0. - ETA: 52s - l - ETA: 49s - loss: 0.1804 - accuracy: 0.929 - ETA: 49s - loss: 0.1804 - accuracy: 0 - ETA: 49s - loss: 0.1804 - accur - ETA: 48s - loss: 0.18 - ETA: 46s - loss: 0.1802 - ac - ETA: 44s - loss: 0.1801 - accura - ETA: 43s - loss: 0.1799 - accuracy: 0. - ETA: 43s - loss: 0.1799 -  - ETA: 41s - loss: 0.1798 - accuracy: 0.929 - ETA: 41s - loss: 0.1798 - accuracy: 0.9 - ETA: 41s - loss: 0.179 - ETA: 3 - ETA: 36s - loss: 0.1798 - ac - ETA: 34s - loss: 0.1798 - accura - ETA: 33s - loss: 0.1798 - accuracy - ETA: 33s - loss: 0.1798 - accu - ETA: 31s - loss: 0.179 - ETA: 29s - loss: 0.1798 - accuracy: - ETA: 29s - loss: 0.1797 - accuracy: - ETA: 28s - loss: 0.1797 - accuracy:  - E - ETA: 24s - loss: 0.1798 - accuracy: 0.929 - ETA: 24s - loss: 0.1798 - accur - ETA: 23s - loss: 0.1796 - accuracy: 0 - ETA: 22s - loss: 0.1797 - acc - ETA: 21s - lo - ETA: 18s - loss: 0.1800 - accuracy: - ETA: 14s - loss: 0.18 - ETA: 6s - loss: 0
# Epoch 14/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1790 - accuracy: 0.9301 - val_loss: 0.1764 - val_accuracy: 0.9336 - E - ETA: 1:46 - loss: - ETA: 1:45 - los - ETA: 1:43 - loss: - ETA - ETA: 1:39 - loss: 0.1824 - accuracy:  - ETA: 1:32 - loss: 0.1814 - accura - ETA: 1:32 - loss: 0.1816 - accura - - ETA: 1:29 - loss: 0 - ETA: 1:28 - loss: 0.181 - ETA: 1:28 - l - ETA - ETA: 1:19 - l - E - ETA: 1:15 - - ETA: 1: - ETA: 1:12 - loss: 0.1799  - ETA: - ETA: 57s - loss: 0 - ETA: 54s - loss: 0 - ETA: 52s - loss: 0.1796 - accuracy: 0.929 - ETA: 52s - loss: 0.1796 - accur - ETA: 51s - loss: 0 - ETA: 49s - loss: 0.1795 - accuracy: 0. - ETA: 49s - loss: 0.1796 - accuracy - ETA: 48s - loss: 0.17 - ETA: 43s - loss: 0.1794 - accuracy:  - ETA: 42s - loss: 0.1 - ETA: 36s - loss: 0.1794 - accuracy: 0. - ETA: 36s - loss: 0.1793 - accu - ETA: 35s - loss: 0.1793 - accuracy: - ETA: 34s - loss: 0.1794 - accu - ETA: 33s - loss: 0.1793 - accuracy: 0.930 - ETA: 33s - loss: 0.17 - ETA: 32 - ETA: 29s - loss: 0.1793 - accuracy: 0.930 - ETA: 28s - loss: 0.1792 - accura - ETA: 28s - loss: 0.1793 - accuracy: 0.9 - ETA: 27s - loss: 0.1793 - accuracy: 0. - ETA: 27s - loss: 0.1793 - accuracy:  - ETA: 26s - loss: 0.1793 - accuracy: 0.930 - ETA: 26s - loss: 0.1793 - accuracy: 0. - ETA: 26s - loss: 0.1793 - accuracy:  - ET - ETA: 22s - loss: 0.1792  - ETA: 21s - loss: 0.1792 - - ETA: 19s - loss: 0.1793 - accuracy: - ETA: 18s - loss: 0.1793 - accu - ETA: 17s - loss: 0.1792 - accu - ETA: 16s - loss: 0.1791 - accuracy: 0.93 - ETA: 16s - loss: 0.1792 - accurac - ETA: 16s - loss: 0.1792 - acc - ETA: 14s - loss:  - ETA: 12s -  - ETA: 8s - loss: 0.1791 - accuracy: 0. - ETA: 7s - loss: 0.1 - ETA: 7s - loss: 0 - ETA: 5s - loss: 0.1792 - accuracy: 0.93 - ETA: 5s - loss: 0.1 - ETA: 4s - l
# Epoch 15/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1774 - accuracy: 0.9307 - val_loss: 0.1703 - val_accuracy: 0.9345TA: 1:08 - loss: 0.1791 - accuracy: 0. - ETA - ETA: 1:06 - loss: 0.1 - ETA: 1:05 - loss: 0.1789 - accuracy: 0.93 - ETA: 1:05 - loss: 0.178 - ETA: 1:04 - loss: 0.179 - ETA: 56s - loss: 0.1792 - ETA: 54s - loss: 0.1790 - accura - ETA: 53s - loss: - ETA: - ETA: 48s - loss: 0.1790 -  - ETA: 46s - loss: 0.1789 - accurac - ETA: 46s - loss: 0.1787 - - ETA: 44s - loss: 0.1787 - accuracy: 0. - ETA: 44s - loss - ETA: 42s - loss: 0.1787 - accuracy: 0.93 - ETA: 41s - loss: 0.1787 - accu - ETA: 40s - loss: 0.1788 - acc - ETA: 39s - loss: 0.1788 - accur - ETA: 38s - loss: 0.1787 - accu - ETA: 33s - loss: 0.1785 - accuracy: 0. - ETA: 33s - loss: 0.1785 - accuracy: - ETA: 32s - loss: 0.1784 - accuracy: 0. - ETA: 32s - loss: 0.1784 - accu - ETA: 31s - loss: 0.1784 - accuracy - ETA: 30s - loss: 0.1783 - accuracy: 0. - ETA: 30s - loss: 0.1 - ETA: 28s - loss: 0.1 - ETA: 26s - loss: 0.1782 - accuracy: - ETA: 26s - loss: 0.1783 - accuracy: 0.9 - ETA: 25s - loss: 0.1783 - accura - ETA: 25s - loss: 0.1784 - accuracy: 0.930 - ETA: 24s - loss: 0.1784 - accuracy: 0.930 - ETA: 24s - loss: 0 - ETA: 22s - loss: 0.1785 - accuracy: - ETA: 22s - loss: 0.1785 - accuracy:  - ETA: 21s - loss: 0.1784 - accurac - ETA: 20s - loss: 0.1785 - a - ETA: 19s - loss: 0.1 - ETA: 17s - los - ETA: 3s - l - ETA: 1s - loss: 0.1775  - ETA: 0s - loss: 0.1775 - accuracy: 0.93 - ETA: 0s - loss: 0.1775 - accuracy: 0. - ETA: 0s - loss: 0.1775
# Epoch 16/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1762 - accuracy: 0.9311 - val_loss: 0.1737 - val_accuracy: 0.9344: 1:41 - loss: 0.1786 - ac - - ETA: 1:33 - loss: 0.1777 - accura - ETA: 1:33 - loss: 0.1778 - accuracy: 0.93 - ETA: 1:33 - loss: 0.1780 - accu - ETA: 1:32 - loss: 0.1777 - accu - ETA: 1:32 - loss: 0.1 - ETA: 1:31 - loss: 0 - ETA: 1:30 - loss: 0.1774 - accuracy: 0. - ETA: 1:29 - loss: 0.1772 - accuracy - ETA: 1:29 - - ETA: 1:22 - loss: - ETA: 1:20 - loss: 0.1756 - accura - ETA: 1:20 - loss: 0.1759 - accu - ETA:  - ETA: 1:12 - loss: 0.1757 -  - ETA: 1:11 - loss: 0.1756  - ETA: 1:11 - los - ETA: 1:08 - loss: 0 - ETA: 1:06 - loss: 0.176 - ETA: 1:06 - loss: 0.1761 - accuracy: 0. - ETA: 1:05 - loss: 0.1762  - ETA: 1:03 - loss: 0.1758 - accuracy: 0. - ET - ETA: 58s - loss: 0.1762 - accur - ETA: 57s - loss: 0.1761 - acc - ETA: 56s - loss: 0.1762 - accuracy: 0.93 - ETA: 55s - loss: 0.1761 - accuracy: - ETA: 55s - loss: 0.1761 - accuracy:  - ETA: 54s - loss: 0.1760 - accuracy: - ETA: 54s - loss: 0.1759 - - ETA: 52s - loss: 0.1762 - accuracy: - ETA: 52s - loss: 0.1761 - - ETA: 50s - loss: 0.1758 - accuracy - ETA: 50s - loss: 0.1759 - accuracy: 0 - ETA: 49s - loss: 0.1761 - accuracy:  - ETA: 49s  - ETA: 34s - loss: 0.1766 - accura - ETA: 33s - loss: 0.1766 - accur - ETA: 33s - loss: 0. - ETA: 31s - loss: 0.1765 - accura - ETA: 30s - loss: 0.1766 - accurac - ET - ETA: 2 - ETA: 19s - - ETA: 16s - loss: 0.1765 - accuracy: 0. - ETA: 15 - ETA: 13s - loss: 0.1768 - accu -  - E - ETA: 7s - E - ETA: 4s - loss: - ETA: 1s - loss: 0.1763 - accuracy: 0.93 - ETA: 1s - loss:
# Epoch 17/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1745 - accuracy: 0.9317 - val_loss: 0.1971 - val_accuracy: 0.9286 - loss: 0.1785 - ac - ETA: 1:54 - loss: 0.1783 - accuracy: 0.93 - ETA: 1:54 - loss: 0 - ETA: 1:51 - loss: 0.1771 - accuracy: 0. - ETA: 1:51 - loss: 0.176 - ETA: 1:50 - loss: 0.1767 - accuracy:  - ETA: 1:50 - loss: 0 - ETA: 1:49 - loss: 0.1766 -  - ETA: 1:46 - loss: 0.1773 - accuracy: 0.93 - ETA: 1:46 - loss: 0.1775 - accuracy: 0. - ETA:  - ETA: 1:40 - loss: - ETA: 1:39 - loss: 0.1757  - ETA: 1:38 - loss: 0.1756 - accuracy: 0.93 - ETA: 1:38 - loss: 0.1756 - accuracy:  - ETA: 1:30 - loss: 0.1746 - accuracy: 0.93 - ETA: 1:30 - loss: 0.174 - ETA: 1:29 - loss: 0 - ETA: 1:28 - loss: 0.1747 - accuracy - ETA: 1:28 - loss: 0.1 - ETA: 1:11 - loss: 0.1752  - ETA: 1: - ETA: 1:08 - ETA: 1:01 - los - ETA: 1:00 - loss: 0.1747 - ETA: 59s - loss: 0.1747 - accuracy: - ETA: 58s - loss: 0.1746 - accuracy: 0.93 - ETA: 58s - loss: 0 - ETA: 56s - loss - ETA: 54s - loss: 0.1752 - accurac - ETA: 53s - loss: 0.1750 - accuracy: 0. - ETA: 52s - loss: 0.1750 -  - ETA: 51s - loss: 0.1751 - acc - ETA: 50s - loss: 0.1749 - accu - ETA: 41s - loss: 0.1746 - accuracy: 0.931 - ETA: 41s - loss: 0.1747 - accuracy: 0.931 - ETA: 41s - loss: 0.174 - ETA: 39s - loss: 0.1750 - accuracy: 0.93 - ETA: 39s - loss: 0.1750 - acc - ETA: 38s - loss: 0.1750 - a - ETA: 37s - loss: 0.1750 - accuracy: 0.931 - ETA: 36s - loss: 0.1750 - accuracy:  - - ETA: 28s - loss: 0.1748 - accu - ETA: 27s - loss: 0. - ETA: 25s - ETA: 23s - loss: 0.1746 - accuracy - ETA: 18s - loss - ETA: 16s - loss:  - ETA: 13s - loss: 0.1747  - ETA: 12s - loss: 0.1747 - accuracy: 0 - ETA: 12s - loss: 0. - ETA: 7s - l - ETA: 6s - loss: 0.1746 - accura - ETA: 6s - loss: 0.1746 - ac - ETA: 0s - loss: 0.1745 - accuracy: 0.93
# Epoch 18/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1733 - accuracy: 0.9322 - val_loss: 0.1676 - val_accuracy: 0.9346: 0.93 - - ETA: 1:54 - loss: 0.1738 - accu - ETA: 1:53 - loss: - ETA: 1:50 - loss: 0.1733 - accuracy:  - ETA: 1:50 - loss: - ETA: 1:45 - - ETA: 1:04 - loss: 0.1741 - accu - ETA: 1:03 - loss: 0.1742 - accu - ETA: 1:01 - loss: 0.1 - ETA: 53s - los - ETA: 50s - loss: 0.1733 - accurac - ETA: 50s - loss: 0.1734 - accura - ETA: 49s - loss: 0.1734 - accuracy:  - ETA: 4 - ETA: 45s - loss: 0.1734 - accur - ETA: 44s - loss: 0.1736 - accur - ETA: 43s - loss: 0.1735 - accu - ETA: 42s - loss: 0.1735 - accu - ETA: 41s - loss: 0. - ETA: 39 - ETA: 36s - ETA: 33s - loss: 0.1734 - accuracy: 0. - ETA: 33s - l - ETA: 30s - loss: 0.1732 - accu - ETA: 29s - loss: 0.1732 - accur - ETA: 28s - loss: 0. - ETA: 26s - loss: 0.1734 - accuracy: 0.93 - ETA: 26s - loss: 0.1734 - accuracy: 0.931 - ETA: 26s - loss: 0.1 - ETA: 24s - loss:  - ETA: 22s - loss: 0.1737 - accurac - ETA: 21s - loss: 0.1736 - a  - ETA: 16s - loss: 0.1735 - acc - ETA: 15s - loss: - ETA: 7s - loss: 0.1732 - accuracy: 0.93 - ETA: 7s - loss: 0.1732 - accura - ETA: 7s - loss: 0.1732 - accuracy: 0.93 - ETA: 7s - loss: 0.1732 - accu - ETA: 6s - loss: - ETA: 3s - loss: - - ETA: 0s - loss: 0.173 - ETA: 0s - loss: 0.1733 - accuracy: 0.93
# Epoch 19/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1723 - accuracy: 0.9326 - val_loss: 0.1922 - val_accuracy: 0.9306: 2:02 - loss: 0.1716 - accuracy: 0.93 - ETA:  - ETA: 1:56 - loss: 0.1717 - accu - ETA: 1:55 - loss: 0.1715 -  - ETA - ETA: 1: - ETA: 1:44 - loss: 0.1731 - accu - ETA: 1:43 - ETA: 1:42 - loss: 0.1720 - accu - ETA: 1:41 - loss: 0.1723 - accu - ETA: 1:41 - loss: 0 - ETA: 1:34 - loss: 0.1720 - accuracy:  - ETA: 1:34 - loss: 0.1721 - accuracy: 0.93 - ETA: 1:33 - loss: 0.172 - ETA: 1:33 - loss: 0.1 - ETA: 1:32 - loss: - ETA: 1:29 - loss: 0.1714 - accuracy: 0. - ETA: 1:28 - loss: 0.1715 -  - ETA: 1:28 - loss: 0.1713 - accuracy: 0.93 - ETA: 1:28 - los - ETA: 1:13 - loss: 0.1713 - accuracy:  - ETA: 1:12 - loss: 0.1715 - accuracy: 0.93 - ETA: 1:12 - loss: 0.1715  - ETA: 1:12 - loss: 0.1715 -  - ETA: 1:11 - loss: - ETA: 1:10 - loss: 0.1717 - accuracy: 0. - ETA: 1:10 - ETA: 1:08 - loss: 0.1718 - accura - ETA: 1:08 - loss: 0 - ETA: 1:07 - loss: 0 - ETA: 1:06 - loss: 0.1715 - accuracy - ETA: 1: - ETA: 1: - ETA: 1:02 - loss: 0.1716  - ETA: 1:01 - loss: 0 - ETA: 1:00  - ETA: 59s - loss: 0.1715 - ac - ETA: 5 - ETA: 54s - loss: 0.1715 - acc - ETA: 53s - loss: 0.17 - ETA: 52s - loss - ETA: 49s - loss: 0.1716 - ETA: 48s - loss: 0.1716 -  - ETA: 46s - loss: 0.17 - ETA: 45s - loss: 0.1717 - acc - ETA: 44s - loss: 0.1717 - accura - ETA: 43s - loss: 0.1718 - accura - ETA: 42s - loss: 0.1717 - acc - ETA: 41s - loss: 0.1717 - accuracy - ETA: 40s - loss: 0.1717 - accuracy: 0 - ETA: 39s - loss: 0.1717 - accu - ETA: 38s - loss: 0.1717 - acc - ETA: 34s - - ETA: 31s - loss: 0.1719  - ETA - ETA: 26s - loss: 0.1720 - accuracy: 0.93 - ETA: 26s - loss:  - ETA: 23s - - ETA: 21s - loss: 0.1723 - accurac - ETA: 16s - loss: 0.1721 - accuracy: 0 - ETA: 16s - loss: 0.1721 - accur - ETA: 15s - loss: 0.172 - ETA: 7s - loss: 0.1722 -  - ETA: 7s - - ETA: 2s - loss: 0.1723 - accu - E
# Epoch 20/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1710 - accuracy: 0.9331 - val_loss: 0.1667 - val_accuracy: 0.936352 - loss: 0.1696  - ETA: 1:51 - loss: 0.1697 - accu - ETA:  - ETA: 1:45 - loss: 0 - - ETA: 1:42 - loss: - E - ETA: 1:39 - loss: 0.1709  - ETA: 1:38 - loss: 0.1713 - accuracy: 0.93 - ETA: 1:38 - loss: 0.1712 - accura - ETA: 1:38 - loss: 0.1714 - ac - ETA: 1: - ETA: 1: - ETA: 1:32 - loss: 0.1706 - accuracy: 0. - ETA: 1:32 - lo - ETA: 59s - loss:  - ETA: 53s - loss: 0.1699 - accuracy: 0.9 - - ETA: 45s - loss: 0.1705 -  - ETA: 44 - ETA: 41 - ETA: 38s - loss - ETA: 36s - loss: 0.1712 - accura - ETA: 31s - loss: 0.1709 - accuracy: 0.933 - ETA: 31s - loss: 0.1709 - ac - ETA: 29s - loss: 0.1710 - ETA: 28s - los - ETA: 25s - loss: 0.1710 - accuracy: - ETA: 25s - loss: 0. - ETA: 23s - loss: 0.1709 - accurac - ETA: 22s - loss: 0.1708 - accuracy: 0 - ETA: 22s - loss: 0.1708 - ETA: 20s - loss: 0.1708 - accuracy: 0.933 - ETA: 20 - ETA: 13s - loss: 0.1711 - accu - ETA: 12s - loss: 0.1710 - accuracy: 0.933 - ETA: 12s - loss: 0.1710 - accu - ETA: 11s - los - ETA: 9s - loss: - ETA: 8s - loss: 0.1711  - ETA: 7s - loss: 0.1712 - accuracy: 0. - ETA: 7s - loss: 0.1711 - accuracy - ETA: 7s - loss: 0.171 - ETA: 6s - loss: 0.1711  - ETA: 5s - loss: 0.1711 - accu - ETA: 1s - loss: 0.1709 - accu - ETA: 0s - loss: 0.1710 - accuracy: 0. - ETA: 0s - loss: 0.1710 - accuracy: 0. - ETA: 0s - loss: 0.1710 - accuracy:
# Epoch 21/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1703 - accuracy: 0.9335 - val_loss: 0.1763 - val_accuracy: 0.9342accuracy:  - ETA: 2:00 - loss: 0.1667 - accuracy:  - ETA: 2:00 - loss: 0.1662  - ETA: 1:59 - loss: 0.1659  - ETA: 1:58 - loss: 0.1654 - accu - ETA: 1:58 - ETA: 1:56 - loss: 0.1699 - accura - ETA: 1:56 - loss: 0.171 - ETA: 1:55 - loss: 0 - ETA: 1:54 - loss: 0.1731 - accuracy: 0.93 - ETA:  - ETA: 1:52 - loss: 0.1742 - accu - ETA:  - E - ETA: 1: - ETA: 1:35 - loss: 0.169 - ETA: 1:34 - loss: 0 - ETA: 1:29 - loss: 0 - ETA: 1:28 - loss: 0.1 - ETA: 1:27 - loss: 0.1704 - accura - ETA: 1:27 - loss: 0.1 - ETA: 1:10 - los - ETA: 1:07 - loss: 0.1705 - accuracy - ETA: 1:07 - ETA: 1:05 - ETA: 1:04 - loss: 0.1704  - ETA: 1:03 - loss: 0.1704 - accuracy:  - ETA: 1:03 - loss: 0.1704  - - ETA: 1:00 - loss: 0.1709 - accuracy: 0.93 - ETA: 1:00 - loss: 0.1709 - accuracy:  - ETA: 1:00 - loss: 0.1710 - accurac - ETA: 59s - loss: 0.1709 - accura - ET - ETA: 55s - loss: 0.1705 - accura - ETA: 54s - loss: 0.1705 - accu - ETA: 53s - loss: 0.1705 - a - ETA: 52s - loss: 0.1704 - ETA: 50s - loss: 0.1704 - accuracy:  - ETA: 50s - loss: 0.1705 - accuracy: 0.9 - ETA: 49s - loss: 0.1705 - - ETA: 48s - loss: 0.1705 - accura - ETA: 47s - - ETA: 44s - loss: 0.1703 - - ETA: 43s - loss: 0.1701 - accuracy: 0 - ETA: 42s - loss: 0.1702 - acc - ETA: 41s - loss: 0.1703 - accu - ETA: 40s - loss: 0.1704 - accuracy: 0.9 - ETA: 40s - loss: 0.1704 - accuracy - ETA: 39s - loss: 0.1705 - accuracy: 0.9 - ETA: 39s - loss: 0.1705 - accura - ETA: 38s - loss: 0.1706  - ETA: 37s - loss: 0.1704 - accuracy:  - ETA: 36s - loss: 0.1703 - ac - ETA: 35s - loss: 0.1706 - accuracy: 0.933 - ETA: 35s - loss: 0.1706 - accura - ETA: 34s - loss: 0.1707 - accur - ETA: 33s - loss: 0.1709 -  - ETA: 32s - loss: 0.1710 -  - ETA: 23s - loss: 0.1708 - - ETA: 21 - ETA: 18s - loss: 0.1705 - accur - ETA: 17s - loss: 0.1705 - accuracy: 0. - ETA: 17s - loss: 0.170 - ETA: 15s - loss: 0.1705 - ac - ETA: 14s - loss: 0.1703 - accuracy - ETA: 13s - loss: 0.1702 - ETA: 9s - l - ETA: 7s - loss: 0.1704 - ac - ETA: 7s - ETA: 5s - loss: 0.1704 - accuracy:  -
# Epoch 22/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1692 - accuracy: 0.9338 - val_loss: 0.1628 - val_accuracy: 0.9374 l - ETA: 1:49 - loss: 0.1667 -  - ETA: 1:48 - loss: 0.167 - ETA: 1:46 - loss: 0.1684 - accuracy:  - ETA: 1:45 - loss: 0.1 - ETA: 1:44 - loss: 0.1679 - accuracy: 0.93 - ETA: 1:44 - l - ETA: 1:43 - loss: 0 - ETA: 1:42 - loss: 0.1684 - accura - ETA: 1:42 - l - ETA:  - ETA: 1:37 - loss: 0.1690 - accuracy: 0. - ETA: 1:36 - loss: 0 - - ETA: 1:34 - loss: 0.1695 - accuracy: 0. - ETA: 1:33 - loss: 0.169 - ETA:  - ETA:  - ETA: 1:29 - loss: 0.1688 -  - ETA: 1:29 - loss: 0.1687 - accura - ETA: 1:28 - - ETA: 1:27 - loss: 0.1691 - accura - ETA: 1:27 - loss: 0.1691 - accuracy:  - ETA: 1: - ETA: 1:23 - loss: 0.1698 -  - ETA: 1:20 - - ETA: 1:19 - loss: 0.1700 - accu - ETA: 1:06 - loss: 0.1696 - accuracy: 0.93 - ETA: 1:06 - loss: 0. - ETA: 58 - ETA: 55s - loss: 0.1703 - accuracy: 0.93 - ETA: 55s - loss: 0.1703 - accuracy - ETA: 54s - loss: 0.1703 - accuracy: - ETA: 54s - loss: 0.1702 - accuracy: 0.9 - ETA: 53s - loss: 0.1701 - accuracy: 0.9 - ETA: 53s - loss: 0.1701 - accur - ETA: 52s - loss: - ETA: 50s - loss: 0.1700 - accu - ETA: 49s  - ETA: 46s - loss - ETA: 40s - loss: 0.1697 - ac - ETA: 39s - loss: 0 - ETA: 37s - lo - ETA: 34s - loss: 0.1694 - acc - ETA: 33s - loss: 0.1694 - accur - ETA: 32s - loss: 0.1695 - accuracy - ETA: 31s - loss: 0.1695 - accur - ETA: 30s - loss: 0.1695 - accuracy: - ETA: 30s - loss: 0.1694 - accuracy - ETA: 29s - loss: 0.1695 - accuracy: 0. - ETA: 29s - loss: 0.1696 - accuracy:  - ETA: 28s - loss: 0.1695 - accur - ETA: 27s - loss: 0.1695 - accuracy: 0.933 - ETA: 27s - loss: 0.1695 - accuracy: 0.933 - ETA: 27s - ETA: 24s - los - ETA: 14s - loss: 0.1690 - accura - ETA: 13s - loss: 0.1690 - ac - ETA: 12s - loss: 0.1691 - accur - ETA: 11
# Epoch 23/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1677 - accuracy: 0.9343 - val_loss: 0.1610 - val_accuracy: 0.937101 - loss: 0.1 - ETA: 2:00 - loss: 0.1707 - accuracy - ETA: 2:00 - loss: 0.1706 - ac - ETA: 2:00 - loss: 0.1712 - accura - ETA: 1:59 - loss: 0 - ETA: 1:58 - loss: 0.1689 - accura - ETA: 1:58 - l - ETA: 1:56 - loss: 0.1686 - accuracy - ETA: 1:56 - - ETA: 1:55 - loss: 0.1693 - ac - ETA: 1:54 - loss: 0.1686 - ac - ETA: 1:53 - loss: 0.1 - ETA: 1:53 - loss: 0.1680 - accuracy: 0.93 - ETA: 1:52 - loss: 0.1 - ETA: 1:50 - loss: 0.1672 - accuracy: 0.93 - ETA: 1:50 - loss: 0 - ETA: 1:49 - loss: 0.1673 - accuracy: 0.93 - ETA: 1:48 - loss: 0.1674 - accuracy: 0.93 - ETA: 1:48 - loss: 0.1674 - accuracy:  - ETA: 1:48 - loss: 0.1677 - accu - ETA: 1:48 - loss: 0.1673 - accuracy: 0. - ETA: 1:47 - loss: 0.1 - E - ETA: 1:43 - loss: 0.1665 - accuracy:  - ETA: 1:43 - - ETA - ETA: 1:39 - loss: 0.1661 - accuracy: 0. - ETA - ETA: 1:38 - loss: 0.1665 - accuracy:  - ETA: 1:37 - loss: 0.1666  - ETA: 1: - ETA  - ETA: 44s - loss: 0.1678 - - ETA: 43s - loss: 0.1678 - ETA: 41s - loss: 0.1677 - accura - ETA: 40s - loss:  - ETA: 38s - loss: 0.1675 - accuracy: 0 - ETA: 38s - loss: 0.1676 - accuracy: 0.93 - ETA: 37s - loss: 0.1676 - accuracy: 0.934 - ETA: 37s - loss: 0.16 - ETA: 36s - loss: 0.1677 - ETA:  - ETA: 23s - loss: 0.1678 - accur - ETA: 22s - loss: 0.1678 - accurac - ETA: 21s - loss: 0.1679 - accuracy: 0.934 - ETA: 21s - loss: 0.1680 - accuracy: 0 - ETA: 21s - loss: 0.1679 - accuracy: 0. - ETA: 21s - loss: 0 - ETA: 19s - loss: 0.1679 - accuracy: 0.93 - ETA: 18s - loss: 0.1 - ETA: 16s - loss: 0.1678 - accuracy: 0.9 - ETA: 16s - loss: 0.1678 - accuracy:  - ETA: 16s - loss: 0.1 - ETA: 4s - loss: 0.1677 - accura - ETA - ETA: 0s - loss: 0.1677 - ac
# Epoch 24/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1673 - accuracy: 0.9344 - val_loss: 0.1645 - val_accuracy: 0.9369: 1:57 - loss: 0.1644  - ETA: 1:57 - ETA: 1:55 - loss: 0.1641 -  - ETA: 1:53 - loss: 0.1 - ETA: 1:52 - loss: 0.1637 - accu - ETA: 1:51 - loss: 0.1636 - accu - - ETA - ETA: 1:37 - loss: 0.1 - ETA: 1:36 - loss: 0.1643 - accura - ETA: 1:36 - loss: 0.1642 -  - ETA: 1:35 - loss: 0.1649 -  - ETA: 1:28 - loss: 0.1657 -  - ETA: 1:28 - loss: 0.1658 - accuracy: 0.93 - ETA: 1:28 - loss: 0.1658 - accuracy - ETA: 1:27 - loss: 0.1660 - ac - ETA: 1:27 - loss: 0.1659 - accura - ETA: 1:26 - loss: 0.1661 - accu - ETA: 1:26 - loss: 0 - ETA: 1:25 - ETA: 1:23 - loss: 0.1665  - ETA: 1:20 - loss: - ETA: 1:19 - loss: 0.1662 - ac - ETA: 1:15 - loss: 0.1664 - accura - ETA: 1:14 - loss: 0.1664 - ac - ETA: 1:14 - loss: 0 - ETA: 1:13 - loss: 0.1663 - accuracy:  - ETA: 1:13 - loss: 0.1664  - ETA: 1:12 - loss: 0.1665 - accuracy: 0.93 - ETA - ETA: 1:10 - l - ETA: 1:09 - loss: 0.166 - ETA: 1:08 - loss: 0 - ETA: 1:07 - los - ETA: 1:04 - loss: 0.1661 - accura - ETA: 1:03 - loss: 0.1662 - accuracy - ETA: 1:03 - loss: 0.1661 - accu - ETA: 1:02 - loss: 0.1 - ETA: 1:01 - loss:  - ETA: 57s - - ETA: 55s - loss: 0.1665 - accuracy: 0.93 - ETA: 54s - loss: 0.166 - ETA: 53s - loss: 0.1665 - accuracy: 0.9 - ETA: 52s  - ETA: 50s - loss: 0.1 - ETA: 48s - loss: 0.1671 - accu - ETA: 47s - loss: 0.1672 - accur - ETA: 46s - loss: 0.16 - ETA: 44s - loss: 0.1673 -  - ETA: 42s - loss: 0.1 - ETA: 41s - loss: 0.1674 - accuracy: 0.9 - ETA: 40s - loss: 0.1673 - accuracy: 0.93 - ETA: 40s - loss: 0.1674 -  - ETA: 39s - loss: 0.1674 - accuracy: 0. - ETA: 39s - loss: 0.1674 - accuracy: 0.93 - ETA: 38s - loss: 0.1674 - accuracy: - ETA: 38s - ETA: 35s - loss: 0.1676 - accuracy: 0 - ETA: 35s - loss: 0.1676 - accuracy: 0.93 - ETA: 34s - loss: 0.1676 - accur - ETA: 33s - loss: 0.1676 - accuracy - ETA: 33s - loss: 0.1677 - accuracy: 0.93 - ETA: 33s - loss: 0.1678 - accura - ETA: 32s - loss: 0.1676 - accuracy: 0.934 - - ETA: 28s - loss: - ETA: 26s - loss - ETA: 23s - loss: 0.1674 - ETA: 22s - loss: 0.1672 - accu - ETA: 21s - los - ETA: 15s - loss: 0 - ETA: 2s - loss: 0.1673 -  - ETA: 1s - los - ETA: 0s - loss: 0.1672 - accuracy
# Epoch 25/50
# 82800/82800 [==============================] - 172s 2ms/sample - loss: 0.1664 - accuracy: 0.9348 - val_loss: 0.1614 - val_accuracy: 0.9362cura
# Epoch 26/50
# 82800/82800 [==============================] - 173s 2ms/sample - loss: 0.1655 - accuracy: 0.9352 - val_loss: 0.1570 - val_accuracy: 0.9394
# Epoch 27/50
# 82800/82800 [==============================] - 175s 2ms/sample - loss: 0.1642 - accuracy: 0.9356 - val_loss: 0.1626 - val_accuracy: 0.9374
# Epoch 28/50
# 82800/82800 [==============================] - 168s 2ms/sample - loss: 0.1637 - accuracy: 0.9358 - val_loss: 0.1599 - val_accuracy: 0.9391
# Epoch 29/50
# 82800/82800 [==============================] - 172s 2ms/sample - loss: 0.1635 - accuracy: 0.9359 - val_loss: 0.1639 - val_accuracy: 0.9382 ETA: 29 - ETA: 26s - loss: 0.1634 - accu - ETA: 2 - ETA: 21s - loss: 0.1635 - ETA: 19s - loss: 0.1634 - ac - ETA: 19s - loss: 0.1634 - accurac - ETA: 18s -  - ETA: 16s - loss: 0.1635 -
# Epoch 30/50
# 82800/82800 [==============================] - 173s 2ms/sample - loss: 0.1625 - accuracy: 0.9362 - val_loss: 0.1579 - val_accuracy: 0.9388
# Epoch 31/50
# 82800/82800 [==============================] - 172s 2ms/sample - loss: 0.1621 - accuracy: 0.9364 - val_loss: 0.1638 - val_accuracy: 0.9394
# Epoch 32/50
# 82800/82800 [==============================] - 172s 2ms/sample - loss: 0.1611 - accuracy: 0.9369 - val_loss: 0.1674 - val_accuracy: 0.9377
# Epoch 33/50
# 82800/82800 [==============================] - 172s 2ms/sample - loss: 0.1608 - accuracy: 0.9368 - val_loss: 0.1538 - val_accuracy: 0.9406
# Epoch 34/50
# 82800/82800 [==============================] - 172s 2ms/sample - loss: 0.1604 - accuracy: 0.9370 - val_loss: 0.1560 - val_accuracy: 0.9393 loss: 0.1604 - ac
# Epoch 35/50
# 82800/82800 [==============================] - 171s 2ms/sample - loss: 0.1592 - accuracy: 0.9376 - val_loss: 0.1563 - val_accuracy: 0.9404
# Epoch 36/50
# 82800/82800 [==============================] - 171s 2ms/sample - loss: 0.1590 - accuracy: 0.9375 - val_loss: 0.1587 - val_accuracy: 0.9397
# Epoch 37/50
# 82800/82800 [==============================] - 172s 2ms/sample - loss: 0.1585 - accuracy: 0.9378 - val_loss: 0.1523 - val_accuracy: 0.9410
# Epoch 38/50
# 82800/82800 [==============================] - 172s 2ms/sample - loss: 0.1581 - accuracy: 0.9381 - val_loss: 0.1550 - val_accuracy: 0.9398
# Epoch 39/50
# 82800/82800 [==============================] - 173s 2ms/sample - loss: 0.1577 - accuracy: 0.9382 - val_loss: 0.1511 - val_accuracy: 0.9417
# Epoch 40/50
# 82800/82800 [==============================] - 172s 2ms/sample - loss: 0.1571 - accuracy: 0.9385 - val_loss: 0.1530 - val_accuracy: 0.9415
# Epoch 41/50
# 82800/82800 [==============================] - 172s 2ms/sample - loss: 0.1565 - accuracy: 0.9385 - val_loss: 0.1538 - val_accuracy: 0.9416 - E - ETA: 2s - loss: 0.1567 - accu - ETA: 2s - ETA: 1s - loss: 0.1566 - accu - ETA: 1s
# Epoch 42/50
# 82800/82800 [==============================] - 171s 2ms/sample - loss: 0.1565 - accuracy: 0.9386 - val_loss: 0.1495 - val_accuracy: 0.9427567 - accuracy - ETA: 41s - lo - ETA: 27s - loss: 0.1564 - accu - ETA: 26s - loss: 0.1565 - accur - ETA: 25s - loss: - ETA: 24s - loss: 0.1567 - accur
# Epoch 43/50
# 82800/82800 [==============================] - 171s 2ms/sample - loss: 0.1558 - accuracy: 0.9389 - val_loss: 0.1562 - val_accuracy: 0.9398
# Epoch 44/50
# 82800/82800 [==============================] - 171s 2ms/sample - loss: 0.1556 - accuracy: 0.9389 - val_loss: 0.1560 - val_accuracy: 0.9387
# Epoch 45/50
# 82800/82800 [==============================] - 172s 2ms/sample - loss: 0.1551 - accuracy: 0.9392 - val_loss: 0.1467 - val_accuracy: 0.943439 - ETA: 39s - loss: 0.1551 - accuracy: 0.939 - ETA: 39s  - E
# Epoch 46/50
# 82800/82800 [==============================] - 167s 2ms/sample - loss: 0.1543 - accuracy: 0.9394 - val_loss: 0.1468 - val_accuracy: 0.9430
# Epoch 47/50
# 82800/82800 [==============================] - 154s 2ms/sample - loss: 0.1543 - accuracy: 0.9395 - val_loss: 0.1530 - val_accuracy: 0.9414racy: 0. - ETA: 54s - loss: 0.1543  - ETA: 50s - loss: 0.1541 - a - ETA: 49s - loss: 0.1541 - accuracy: 0.9 - ETA: 49s - loss: 0.1541 - accuracy:  - ETA - ETA: 34s - los - ETA: 32s - loss: 0.1542 - accuracy: 0. - ETA - ETA: 19s - los - ETA: 17s - loss: 0.1542 - ac - ETA: 16s - ETA: 14s - lo - ETA: 12s - loss: 0.1541 - a
# Epoch 48/50
# 82800/82800 [==============================] - 146s 2ms/sample - loss: 0.1539 - accuracy: 0.9395 - val_loss: 0.1484 - val_accuracy: 0.9432 - ETA:  - ETA: 1:46 - l - ETA: 1:37 - loss: 0.1524 - accu - ETA - ETA: 1:32 - loss: 0.1532 - accura - ETA: 1:32 - loss: 0.153 - ETA: 1: - ETA: 1:22 - l - ETA: 1:21 - loss: 0.1535 -  - ETA:  - ETA: 1:18 - loss: 0.1536 -  - ETA: 1:18 - loss: 0.153 - ETA: 1: - ETA: 1:13 - loss: 0.1538 -  - ETA: 1:12 - loss: 0.1543 - accuracy - - ETA: 58s - loss: 0.1538 - accuracy: 0.939 - ETA: 58s - loss: 0.15 - ETA: 56s - loss: 0.1537  - ETA: 53s - loss - ETA: 51s - loss: 0 - ETA: 50s - loss: 0. - ETA: 48s - loss: 0.1539 - accuracy: 0.939 - ETA: 48s - loss: 0.15 - ETA: 47s - loss: 0 - ETA: 46s - loss: - ETA: 44s - loss: 0.1537 - accuracy: 0. - ETA: 44s - loss: - ETA: 42s - loss: 0. - ETA: 38s - loss: 0.1539 - accuracy: 0.9 - ETA: 38s - loss: 0.1539 - accuracy: 0. - ETA: 37s - loss: 0.1539 - accu - ETA: 37s - loss: 0.1541 - accuracy:  - ETA: 36s - loss: 0.1540 -  - ETA: 35s - loss: 0.1540  - ETA: 25s - loss: 0 - ETA: 24s - loss: 0.1541 - ETA: 23s - loss: 0.1542 - ETA: 21s - loss: 0.1541 -  - ETA: 20s - loss: 0.1540 -  - ETA: 19s - loss: 0.1541 - accura - ETA: 19s - loss: 0.1541 - ETA: 15s - ETA: 12s - loss: 0.1539 - ac - ETA: 11s - loss: 0.1540 - ETA: 0s - loss: 0.1539 - accura
# Epoch 49/50
# 82800/82800 [==============================] - 148s 2ms/sample - loss: 0.1536 - accuracy: 0.9397 - val_loss: 0.1475 - val_accuracy: 0.9434: 2:09 - loss: 0.151 - ETA: 1:12 - loss: 0.1544 - accu - ETA: 1:11 - loss: - ETA: 1:10 - loss: 0.1545 - accuracy:  - ETA - ETA: 58s - loss: 0.1540 - accuracy: 0 - ETA: 57s - loss: 0.154 - ETA: 56s - loss: 0.1539 - accuracy:  - ETA: 55s - loss:  - ETA: 54s - lo - ETA: 52s - loss - ETA: 50s - loss: 0.1540 - accuracy: 0.9 - ETA: 50s - loss: 0.1539 - ac - ETA: 49s - loss: 0.1540 - accurac - ETA: 49s - loss: 0.1540 - accura
# Epoch 50/50
# 82800/82800 [==============================] - 147s 2ms/sample - loss: 0.1532 - accuracy: 0.9398 - val_loss: 0.1480 - val_accuracy: 0.942650s - loss: 0.1540 - accuracy: 0. - ETA: 49s - loss: 0.1540 - accuracy: 0. - ETA: 49s - loss:  - ETA: 47s - loss: 0.1539 - accurac - ETA: 47s - ETA: 45s - ETA: 42s - loss: 0.1533 - accuracy: 0 - ETA:  - ETA: 36s - loss: 0.153 - ETA: 35s - loss: 0

# %%
# plot train and validation loss 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show(); plt.close()

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
#load for validation different directrory different ids
coco_instances = COCO(os.path.join(dataDir,r"annotations\instances_" + val_data_name + ".json"))

# in the .getCatIds(catNms=[list of all ids we want to filter from the data]);
catIds = coco_instances.getCatIds(catNms=categories_names);

# get all the image id for all images here its for the validation
all_imgIds = coco_instances.getImgIds();

# get all the image id for all images based on the filter
imgIds = coco_instances.getImgIds(catIds=catIds);

img_list = []
mask_list = []

for cnt, imgID in enumerate(all_imgIds):
    I = cv2.imread(os.path.join(dataDir, val_data_name +r"//" +str(imgID).zfill(12) + ".jpg"),rgb_on)
    I = cv2.resize(I, dsize=(img_width, img_height), interpolation=cv2.INTER_CUBIC)
    img_list.append(I)
    
    if (imgID in imgIds):
        annIds = coco_instances.getAnnIds(imgIds=imgID, catIds=catIds, iscrowd=None)
        anns = coco_instances.loadAnns(annIds)
        img_data = coco_instances.loadImgs(imgID)[0]
        anns_img = np.zeros((img_height, img_width),)
        for ann in anns:
            mask_res = cv2.resize(coco_instances.annToMask(ann), (img_height, img_width), interpolation = cv2.INTER_AREA )
            anns_img = np.maximum(anns_img, mask_res*(catIds.index((ann['category_id']))+1))
        
        #mask = cv2.resize(anns_img, dsize=(img_width, img_height), interpolation=cv2.INTER_CUBIC)    
        #save mask to disk
        #cv2.imwrite(r"E:\Documents\Study\Deep Learning\Project\TestMASKS\\" +str(imgID).zfill(12) + ".png" , mask)
    else:
        anns_img = np.zeros((img_height, img_width),)
        
    mask_list.append(anns_img)
    
    if (cnt+1 == max_cnt_debug_test):
        break
    
#y_train = read_data(r'E:\Documents\Study\Deep Learning\Project\MASKS')
#y_train = (to_categorical(y_train)).astype('float')

y_test = np.asarray(mask_list)
#y_test = (np.expand_dims(y_test, axis=3)).astype('float')
y_test = (to_categorical(y_test, num_classes=2, dtype='float32')).astype('float')


x_test = np.asarray(img_list).astype('float')

if (rgb_on == 0):
    x_test = (np.expand_dims(x_test, axis=3)).astype('float')

print('x_test shape:', x_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# loading annotations into memory...
# Done (t=0.53s)
# creating index...
# index created!
# x_test shape: (10, 64, 64, 3)
# y_test shape: (10, 64, 64, 2)

# %%
plt.subplot(3,3,1)
plt.imshow(np.squeeze(x_test[0,:,:].astype('uint8')))
plt.axis('off')

plt.subplot(3,3,2)
plt.imshow(np.squeeze(x_test[1,:,:].astype('uint')))
plt.axis('off')

plt.subplot(3,3,3)
plt.imshow(np.squeeze(x_test[2,:,:].astype('uint')))
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
#plt.hist((coco_instances.annToMask(ann)*49).ravel(),256, [0,255]);
#plt.hist(mask_list[0].ravel(),256, [0,255]);
#plt.imshow(mask_list[0])

# %%
y_pred = loaded_model.predict(x_test)

# %%
y_pred = model.predict(x_test)
test_loss, test_acc = model.evaluate(x_test, y_test)

# Print results
print('test loss:', test_loss)
print('test accuracy:', test_acc)
# Out:
# 10/1 [============================================================================================================================================================================================================================================================================================================] - 0s 24ms/sample - loss: 0.0826 - accuracy: 0.9764
# test loss: 0.08256473392248154
# test accuracy: 0.9763916

# %%
# #Visialize the source image
# img = cv2.imread(os.path.join(dataDir, data_name +r"//" +str(imgIds[0]).zfill(12) + ".jpg"),0)
# plt.imshow(img)

# %%
#Visialize the resized image
# visualize the predicted resaults vs the real resaults
img_idx = 3

if (rgb_on == 0):
    plt.imshow((x_test[img_idx,:,:,0]).astype('uint8'))
else:
    plt.imshow((x_test[img_idx,:,:]).astype('uint8'))
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
# visualize the predicted resaults vs the real resaults

plt.subplot(3,2,1)
plt.imshow((y_pred[img_idx,:,:,0]*255).astype('uint8'))
plt.axis('off')

plt.subplot(3,2,2)
plt.imshow((y_pred[img_idx,:,:,1]*255).astype('uint8'))
plt.axis('off')

plt.subplot(3,2,3)
plt.imshow((y_test[img_idx,:,:,0]*255).astype('uint8'))
plt.axis('off')

plt.subplot(3,2,4)
plt.imshow((y_test[img_idx,:,:,1]*255).astype('uint8'))
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
# auc roc for the good model the fist class
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# Plot linewidth.
lw = 2

# Compute ROC curve and ROC area for each class
fpr, tpr, _ = roc_curve(y_test[:,:,:,0].flatten(), y_pred[:,:,:,0].flatten())
roc_auc = auc(fpr, tpr)


plt.plot(fpr, tpr, color='green', lw=lw,label='ROC curve of class (AUC = {0})' ''.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic COCO person recognition')
plt.legend(loc="lower right")
plt.show()
