# %%
# %matplotlib inline

import os
from glob import glob
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
 
from tensorflow.keras.models import Model, model_from_json
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Flatten, Dense, concatenate

from tensorflow.keras.layers import Softmax
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers
from sklearn.metrics import confusion_matrix
from plot_confusion_matrix import plot_confusion_matrix
from tensorflow.keras.callbacks import Callback
import cv2
import time

pylab.rcParams['figure.figsize'] = (8.0, 10.0)

# %%
def read_data(directory):
# =============================================================================
#  This function gets a directory name and returns all images in it concatenated 
#  to each other
# =============================================================================    
    data_list = glob(os.path.join(directory ,r'*.png'))
    #print(os.path.join(directory,'*.png'))
    data = np.asarray([cv2.imread(img,0) for img in data_list])
    return data

# %%
class TimeHistory(Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
# display COCO categories and supercategories
# cats = coco.loadCats(coco.getCatIds())
# nms=[cat['name'] for cat in cats]
# print('COCO categories: \n{}\n'.format(' '.join(nms)))

# nms = set([cat['supercategory'] for cat in cats])
# print('COCO supercategories: \n{}'.format(' '.join(nms)))

# %%
# the index of the image from the set just to visualize

img_idx = 0

dataDir = "E:\Documents\Study\Deep Learning\Project\DATA"
train_data_name = "train2017"
val_data_name = "val2017"

# we resize the images because of memory limitations on my 32GB RAM and 4GB GPU memory
img_width = 64
img_height = 64

# size of the data set for debug {None => all the data} 
max_cnt_debug_train = None
max_cnt_debug_test = None

# load images in grayscale or in RGB when rgb_on = 1 it will load rgb images
rgb_on = 1

# parameters for the training model number of classes will be autometicly generated based on the number of categories
lr =          1e-3        # learning rate 
beta_1 =      0.9         # beta 1 - for adam optimizer
beta_2 =      0.99        # beta 2 - for adam optimizer
epsilon =     1e-7        # epsilon - for adam optimizer
epochs =      50          # number of epochs
bs =          32          # batch size
dp =          0.5         # dropout probability


# in the .getCatIds(catNms=[list of all ids we want to filter from the data]);
categories_names = ['person']

# %%
# load captions
#coco_caps= COCO(os.path.join(dataDir,r"annotations\captions_" + data_name + ".json"))

# Load insatnces -> here we take the masks
coco_instances = COCO(os.path.join(dataDir,r"annotations\instances_" + train_data_name + ".json"))

# Load key points
#coco_key_p = COCO(os.path.join(dataDir,r"annotations\person_keypoints_" + data_name + ".json")) 

# get the id for each category specified
catIds = coco_instances.getCatIds(catNms=categories_names);

#get all image id in the directory
all_imgIds = coco_instances.getImgIds()

# get all the image id for all images based on the filter
imgIds = coco_instances.getImgIds(catIds=catIds);

# get the data for each image id with specified annotations
img_data = coco_instances.loadImgs(imgIds)

# Visualize the img_idx specified up here
I = io.imread(os.path.join(dataDir, train_data_name +r"//" +str(imgIds[img_idx]).zfill(12) + ".jpg"))
plt.imshow(I); 
plt.axis('off')
plt.title("image id: " + str(imgIds[img_idx]))

# and show the mask on top of the image
annIds = coco_instances.getAnnIds(imgIds=imgIds[img_idx], catIds=catIds, iscrowd=None)
anns = coco_instances.loadAnns(annIds)
coco_instances.showAnns(anns)

#plot key points
#annIds_keys = coco_key_p.getAnnIds(imgIds=imgIds[idx], catIds=catIds, iscrowd=None)
#anns_keys = coco_key_p.loadAnns(annIds_keys)
#coco_key_p.showAnns(anns_keys)

#print the caption
#annIds = coco_caps.getAnnIds(imgIds=imgIds[idx]);
#anns = coco_caps.loadAnns(annIds)
#coco_caps.showAnns(anns)
# Out:
# loading annotations into memory...
# Done (t=13.12s)
# creating index...
# index created!

# %%
#visualize the mask of the annotaion
# every annotation has a id (number) for every pixel on the mask we multiply by id
# pixel = id = we have annotation in the pixel
# pixel = 0 we dont have annotation in that spot
anns_img = np.zeros((img_data[img_idx]['height'],img_data[img_idx]['width']))
for ann in anns:
    #mask += coco_instances.annToMask(anns[i])*anns[i]['category_id'] 
    anns_img = np.maximum(anns_img, coco_instances.annToMask(ann)*ann['category_id'])
    
#plt.subplot(2,1,1)    
plt.imshow(anns_img)
plt.axis('off')
#plt.subplot(2,1,2)
# Visuaslize the histogram of the mask
#plt.hist(anns_img.ravel(),256, [0,50]);
# Out:
# (-0.5, 639.5, 426.5, -0.5)

# %%
mask_list = [] # init empty list for masks

# we load all the images in grayscale because of memory limitations
img_list = [] # init empty list to store all the image data

for cnt, imgID in enumerate(all_imgIds):
    I = cv2.imread(os.path.join(dataDir, train_data_name +r"//" +str(imgID).zfill(12) + ".jpg"), rgb_on)
    I = cv2.resize(I, dsize=(img_width, img_height), interpolation=cv2.INTER_CUBIC)
    img_list.append(I)
    
    if (imgID in imgIds):
        # get all annotation ids for img id
        annIds = coco_instances.getAnnIds(imgIds=imgID, catIds=catIds, iscrowd=None) 
        # load all annotation inside the image
        anns = coco_instances.loadAnns(annIds) 
        # image data for image specification width height etc..
        #img_data = coco_instances.loadImgs(imgID)[0] 
    
        # init empty mask
        anns_img = np.zeros((img_height, img_width),) 
        for ann in anns:
            # resize the mask of the  specific anotation in the image
            mask_res = cv2.resize(coco_instances.annToMask(ann), (img_height, img_width), interpolation = cv2.INTER_AREA )
            # add the mask multiplid by the category index for category 
            # here we multiply by the index of the annotation +1
            # for easier way to_categories
            # if we have only one category it will be mask of only zeros ans ones
            # if we would multiply by the category id the to_category will make more categories then we need
            # for example if the category is 17 it will generate 18 categories and we need only 2
            anns_img = np.maximum(anns_img, mask_res*(catIds.index(ann['category_id'])+1))
    else:
        anns_img = np.zeros((img_height, img_width),)
    # for debug save the mask to the disk
    #cv2.imwrite(r"E:\Documents\Study\Deep Learning\Project\MASKS\\" +str(imgID).zfill(12) + ".png" , anns_img)
    mask_list.append(anns_img)
    
    if (cnt+1 == max_cnt_debug_train):
        break

# read the masks from the disk
#y_train = read_data(r'E:\Documents\Study\Deep Learning\Project\MASKS')
#y_train = (to_categorical(y_train)).astype('float')

y_train = np.asarray(mask_list)
y_train = (to_categorical(y_train, num_classes=None, dtype='float32')).astype('float')

x_train = np.asarray(img_list)
if (rgb_on == 0):
    x_train = (np.expand_dims(x_train, axis=3)).astype('float')

print('y_train shape:', y_train.shape)
print('x_train shape:', x_train.shape)
# Out:
# y_train shape: (118287, 64, 64, 2)
# x_train shape: (118287, 64, 64, 3)

# %%
#visualize the first image from the set
I = io.imread(os.path.join(dataDir, train_data_name +r"//" +str(imgIds[0]).zfill(12) + ".jpg"))
#I = cv2.cvtColor(I, cv2.COLOR_RGB2BGR)

#Visualize the image
plt.subplot(2,1,1)    
plt.imshow(I)
plt.axis('off')
#visualize the histogram of the image
plt.subplot(2,1,2)   
plt.hist(I.ravel(),256, [0,255]);

# %%
# number of classes for prediction based on the to_categorial
num_of_clss = y_train.shape[3]  # number of classes (the number of the categories form the to_categorial by keras)

# %%
inp = Input(shape = (x_train.shape[1],x_train.shape[2],x_train.shape[3]))

# First conv block
x = Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(inp)
x = Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(dp)(x)

# Second conv block
x = Conv2D(32, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = Conv2D(32, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

# Third conv block
x = Conv2D(16, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = Conv2D(16, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = Conv2D(16, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(dp)(x)
# DECONV AND UNPOOLING

x = Conv2DTranspose(16, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2DTranspose(32, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2DTranspose(64, (3, 3), strides=(1, 1), padding='same', activation = 'relu')(x)
x = UpSampling2D((2, 2))(x)

out = Conv2DTranspose(num_of_clss, (3, 3), strides=(1, 1), padding='same', activation = 'softmax')(x)

model = Model(inp,out)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        18464
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 16)        4624
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 16)        2320
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 16)        2320
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 16)        64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 16)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 16)          2320
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 32)        4640
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 64)        18496
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 64, 64, 2)         1154
# =================================================================
# Total params: 102,754
# Trainable params: 102,530
# Non-trainable params: 224
# _________________________________________________________________

# %%
# define the optimizer and compile the model
adam = optimizers.Adam(lr=lr, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
time_callback = TimeHistory()
history = model.fit(x_train, y_train, validation_split=0.3, epochs=epochs, batch_size=bs, callbacks=[time_callback])
times = time_callback.times
print(times)
# Out:
# Train on 82800 samples, validate on 35487 samples
# Epoch 1/50
# 82800/82800 [==============================] - 150s 2ms/sample - loss: 0.2352 - accuracy: 0.9131 - val_loss: 0.2339 - val_accuracy: 0.9200 - ETA: 2:52 - los - ETA:  - ETA: 2:17 - - ETA - ETA: 2:06 - loss: 0.2740 -  - ETA: 2:05 - loss: 0.2737 - accura - ETA: 2:04 - loss: - ETA - ETA: 1:54 - loss: 0 - ETA: 1:52 - loss: 0.2700 - accuracy: 0.90 - ETA: 1:52 - loss: 0.2699 - accuracy:  - ETA: 1:52 - loss: 0.2697 - accuracy: 0. - ETA: 1:52 - l - ETA: 1:50 - l - ETA: 1:48 - loss: 0.268 - ETA: 1:47 - loss: 0.2673 -  - ETA: 1:46 - loss: - ETA: 1:40 - loss: 0.2641 -  - ETA: 1:39 - loss: 0.2 - ETA: 1:34 - l
# Epoch 2/50
# 82800/82800 [==============================] - 145s 2ms/sample - loss: 0.2036 - accuracy: 0.9211 - val_loss: 0.1989 - val_accuracy: 0.9244
# Epoch 3/50
# 82800/82800 [==============================] - 147s 2ms/sample - loss: 0.1923 - accuracy: 0.9253 - val_loss: 0.1818 - val_accuracy: 0.9299 - loss: 0 - ETA: 18s - loss: 0.1929 -  - ETA: 16s - loss: 0.192 - ETA: 14s - loss: 0.19 - ETA: 1 - ETA: 4s - loss: - ETA:
# Epoch 4/50
# 82800/82800 [==============================] - 147s 2ms/sample - loss: 0.1857 - accuracy: 0.9277 - val_loss: 0.1755 - val_accuracy: 0.93231:37 - loss: 0.1866 - accu - ETA: 1:36 - loss: 0.1864 - accu - ETA: 1:36 - loss: 0 - ETA: 1:35 - - ETA - ETA: 1:31 - loss: 0.1875 - ac - ETA:  - ETA: 1:29 - loss: 0.1865 - accuracy: 0.92 - ETA: 1:29 - loss: 0.1866 - accu - ETA: 1:28 - loss: 0.1865 - accu - ETA: 1:27 - loss: - ETA: 1:26 - loss: 0.1869 - accuracy:  - ETA: 1:26 - loss: - ETA: 1:23 - loss: 0 - ETA: 1:22 - l - ETA: 1:21 - los - ETA: 1:19 - loss: - ETA: 1:18 - loss: 0.1868  - ETA: 1
# Epoch 5/50
# 82800/82800 [==============================] - 148s 2ms/sample - loss: 0.1808 - accuracy: 0.9297 - val_loss: 0.1705 - val_accuracy: 0.934456s - loss: 0.1821 - accuracy: - ETA: 56s - loss: 0.1822 - accura - ETA: 55s - loss: 0.1821 - accuracy: 0.9 - ETA: 55s - loss: 0.1821 - acc - ETA: 54s - loss: 0.1818 - ac -  - ETA: 49s - loss: 0.1818 - - ETA: 48s - lo - ETA: 45s - loss: 0.1816 -  - ETA: 44s - loss: 0.1817 - accuracy: 0.929 - ETA: 44s - loss: 0.1817 - accuracy - ETA: 43s - ETA: 41s - loss: 0.1815 - acc - ETA: 40s - l - ETA: 37s - loss: 0.1815 - ac - ETA: 2s - loss: 0.1811
# Epoch 6/50
# 82800/82800 [==============================] - 145s 2ms/sample - loss: 0.1770 - accuracy: 0.9312 - val_loss: 0.1628 - val_accuracy: 0.9371oss: 0.1786 - accura - ETA:  - ETA: 1:39 - loss: 0.1779 - ac - ETA: 1:38 - loss: 0.1778 - accuracy:  - ETA: 1:38 - ETA: 1:37 - ETA: 1:35 - los - ETA: 1:34 - loss: 0.1779  - ETA: 1:31 - loss: 0.1 - ETA: 1:29 - loss: 0.177 - ETA: 1:29 - loss: 0.1777 - accuracy: 0.93 - ETA: 1:29 - loss: 0.1777 - accuracy: 0.93 - ETA: 1:28 - loss: 0.1777 - accuracy: 0.93 - ETA: 1:28 - loss: 0.177 - ETA: 1:27 - loss: 0.1773 - accura - ETA: 1:25 - loss: 0.1769 - accu - ETA: 1:24 - loss: 0.1767 - accuracy: 0.93 - E - ETA: 1:22 - loss: 0.1769 - accuracy:  - ETA: 1:22 - loss: 0.1768  - ETA: 1:21 - loss: 0.1770 - accuracy: 0.93 - ETA: 1:21 - loss: 0.1771  - ETA: 1:20 - loss: 0.1771 - accura - ETA: 1:20 - loss: 0.177 - ETA: 1:12 - - ETA: 1:07 - los - ETA: 1:06 - loss: 0.1779 - accuracy - ETA: 1:05 - loss: 0.1779 - accuracy:  - ETA: 1:05 - loss: 0.1779 -  - ETA: 1:04 - loss: 0.1780  - ETA: 1:03 - loss: 0 - ETA: 1:02 - loss: 0.1779 - accuracy: 0.93 - ETA: 1:02 - loss: 0.1779 - accuracy:  - ETA: 1:02 - loss: 0.1779 - accu - ETA: 1:02 - - ETA: 1:00 - loss: 0.1778 - accu - ETA: 1:00 - loss: 0.1779 - accuracy: 0 - ETA: 59s - loss: 0.1779 - accura - ETA: 58s - loss: 0.1780 - accura - ETA: 57s - loss: 0.1778 - accuracy: 0.93 - ETA: 57s - loss: 0.1777 - accura - ETA: 56s - loss: 0.1777 - accura - ETA: 55s - loss: 0.1777 - - ETA: 54s - loss: 0.1775  - ETA: 52s - loss: 0.1773 - accuracy: 0. - ETA: 52s - loss: 0.1773 - accuracy: 0. - ETA: 52s - loss: 0.1773 - accuracy: - ETA: 51s - loss: 0.1776  - ETA: 49s - loss: 0.1776 - accuracy: 0.931 - ETA: 49s - loss: 0. - ETA: 47s - loss: 0.1777 - accuracy: 0.93 - ETA: 47s - loss: 0 - ETA: 45s - loss: 0.1776 - accurac - ETA: 44s - loss: 0.1777 - a - ETA: 43s - l - ETA: 40s - loss:  - ETA: 38s - loss: 0.1776 - accura - ETA: 37s - loss: 0.1776 - accuracy: 0.931 - ETA: 37s - loss: 0.1776 - accuracy: 0.9 - ETA: 37s - loss: 0.1776 - accuracy: - ETA: 36s - loss: 0.1776 - accuracy: 0 - ETA: 35s - loss: 0.1776 - accuracy: - ETA: 35s - loss: 0.1775 - accuracy: 0.93 - ETA: 35s - - ETA: 32s - loss: 0.1773 -  - ETA: 31s - loss: 0.1775 - accuracy: 0.931 - ETA: 30s - loss: - ETA: 28s - loss: 0.1774 - accuracy: 0. - ETA: 28s - loss: 0.1774 - accuracy: 0 - ETA: 27s - loss: 0.1773 - accuracy: 0. - ETA: 27s - loss: - ETA: 25s - loss: 0.1772 - accur - ETA: 24s - loss: 0.1772 - accuracy: 0.931 -  - ETA: 20s - loss: 0.1771 - accuracy: 0.9  - ETA: 16s - loss: 0.1771 - acc - ETA: 15s - loss: 0.1771 - accuracy: 0.93 - ETA: 15s - loss: 0.1772 - accuracy: 0.931 - ETA: 15s - loss: 0.1772 - accurac - ETA: 14s - loss: 0.1772 - accur - ETA: 13s - ETA: 10s - loss: 0.1774 - accuracy: 0.931 - ETA: 10s - loss: 0.1773 - accuracy: 0.9 - ETA: 10s - loss:  - ETA: 8s - loss: 0 - ETA: 6s - loss: 0 - ETA: 4s - loss: 0.1773 - accura - ETA - ETA: 0s - loss: 0.1771 - ac - ETA: 0s - loss: 0.1770 - accuracy
# Epoch 7/50
# 82800/82800 [==============================] - 146s 2ms/sample - loss: 0.1736 - accuracy: 0.9324 - val_loss: 0.1713 - val_accuracy: 0.9340oss: 0.1643 - accuracy - ETA: 2:01 - loss: 0.1695 -  - ETA: 2:02 - loss: 0.1708 - accuracy: 0. - ETA: 2:01 - loss: 0.1676 - accuracy:  - ETA: 2:01 - loss: 0.1694 -  - ETA: 2:00 - loss: - ETA: 1:59 - loss: 0 - ETA: 1:58 - loss: 0.1760 - accuracy:  - ETA: 1: - ETA: 1:54 - loss: 0.1 - ETA: 1:53 - loss: 0 - ETA: 1:52 - loss: 0.1789 - ac - ETA: 1:52 - - ETA: 1:50 - loss: 0.1800  - ETA: 1:49 - loss: 0.1795 - accuracy: 0.93 - ETA: 1:49 - loss: 0.1793 - accu - E - ETA: 1:47 - loss: 0.1 - - ETA: 1:44 - loss: 0.1773 - accura - ETA: 1:44 - ETA: 1:42 - loss: 0.177 - ETA: 1:41 - loss: 0.1760 - accuracy:  - E - ETA: 1:03 - loss: 0.1741 - accuracy:  - ETA: 1:03 - loss: 0.1740 - ac - ETA - ETA: 54s - loss: 0.1739 - accuracy: 0 - ETA: 54s - loss: 0.1741 - accu - ETA: 49s -  - ETA: 40s - loss: 0.1738  - ETA: 38s - loss: 0.1736 - accuracy:  - ETA: 38s - loss: 0.1737 - accuracy: 0. - ETA: 37s - loss: 0.1736 - accuracy - ETA: 37s - loss: 0.1736 - accuracy: 0.932 - ETA: 37s - loss: 0.1736 - accuracy: 0. - ETA: 37s - loss: 0.1736 - accurac - ETA: 36s - loss: 0.17 - ETA: 0s - loss: 0.1736 - accuracy: 0.93
# Epoch 8/50
# 82800/82800 [==============================] - 152s 2ms/sample - loss: 0.1713 - accuracy: 0.9334 - val_loss: 0.1652 - val_accuracy: 0.9343
# Epoch 9/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1685 - accuracy: 0.9345 - val_loss: 0.1583 - val_accuracy: 0.9383accura - ETA: 1:50 - loss: 0.1 - ETA: 1:49 - loss: 0.1706 - accura - ETA: 1:48 - loss: 0.1707 - accura - ETA: 1:48 - loss: 0.1703 - ac - ETA: 1:45 - loss: 0.1693 - accura - ETA:  - ETA: 1:43 - loss: 0.1697 - accuracy: 0.93 - ETA: 1:43 - loss: 0.1698  - ETA: 1:42 - loss: 0 - ETA: 1:41 - loss: 0.1695 - accuracy:  - ETA: 1:41 - loss: 0.1 - ETA: 1:40 - loss: 0.1 - ETA: 1:32 - loss: 0.1690 - ac - ETA: 1:31 - loss: 0.1690 - accuracy: 0.93 - ETA: 1:31 - loss: 0.1691 - accuracy - ETA: 1:31 - loss: 0.1689 - ac - ETA: 1:30 - loss: 0.169 - ETA: 1:30 - los - ETA: 1:28 - loss: 0.1689 - accuracy: 0.93 - ETA: 1:28 - loss: 0.1689 - accuracy - ETA: 1:28 - loss: 0.1689 - accuracy:  - ETA: 1:28 - loss: 0.1688 - accuracy: 0. - ETA: 1:25 - loss: 0 - ETA: 1:24 - loss: 0.1687  - ETA: 1:24 - loss: 0.1690 - accuracy:  - ETA: 1:23 - loss: 0.1 - ETA: 1:20 - loss: 0 - ETA: 1:17 - loss: 0.169 - ETA: 1:17 - ETA: 1:15 - loss: 0.1689 - accuracy: 0.93 - ETA: 1:15 - loss: 0.1689  - ETA: 1:14 - loss: 0.1689 -  - ETA: 1:13 - loss: 0.1688 - accuracy: 0.93 - ETA: 1:13 - loss: 0.1688 - accuracy: 0.93 - ETA: 1:13 - loss: 0.1688 - accuracy:  - ETA: 1:13 - loss: 0.1686  - ETA - ETA: 1:10 - loss: 0.1685 - accuracy:  - ETA: 1:10 - loss: 0.1685 - accuracy - ETA: 1:08 - loss: 0.1683 -  - ETA: 1:07 - loss: 0.1684 - accuracy: 0. - E - ETA: 1:05 - loss: 0.1677 - accuracy: 0. - E - ETA: 1:03 - loss: 0.167 - E - ETA: 1:00 - loss: 0.1676 - accuracy: 0.93 - ETA: 1:00 - loss: 0.1676 - accuracy: 0.93 - ETA: 1:00 - loss: 0.1675 - ac - ETA: 59s - loss: 0.1674 - accuracy: 0.934 - ETA: 59s - loss: 0.1673 - ac - ETA: 58s - loss: 0.1676 - accura - ETA: 57s - loss: 0.1676 - accura - ETA: 56s - loss: 0.1676 - accuracy: 0 - ETA: 56s - loss: 0.1676 - accuracy: - ETA: 55s - loss: 0.1676 - accuracy: 0.934 - ETA: 55s - loss: 0.1677 - accuracy: 0.934 - ETA: 55s - loss: 0.1677 - accu - ETA: 54s - loss: 0.1677 - accura - ETA: 53s - loss: 0.1678 - accuracy - ETA: 52s - loss: 0.1678 - accuracy: - ETA: 52s - loss: 0.1678 -  - ETA: 50s - loss: 0.1679 - ac - ETA: 49s - loss - ETA: 47s - loss: 0.1678 - accurac - ETA: 46 - ETA: 43s - loss: 0.1681 - ac - ETA: 42s - loss: 0.1680 - accuracy: - ETA: 41s - loss: 0.1679 - accuracy: 0.934 - ETA: 41s - loss: 0.1679 - accuracy: 0.934 - ETA: 41s - loss: 0.1679 - acc  - ETA: 36s - loss: 0.1678 - accuracy: 0.93 - ETA: 36s - loss: 0.1679 - accura - ETA: 35s - loss: 0.1678 - accura - ETA: 34s - loss: 0.1676 - accurac - ETA: 33s - loss - ETA - ETA: 27s - loss: 0.1680 - accuracy: 0 - ETA: 27s - loss: 0.1682 - accuracy: 0. - ETA: 26s - loss: 0.1682 - ETA: 25s - loss: 0.1682 - acc - ETA: 24s - loss: 0.1681 - accuracy: 0.93 - ETA: 24s - loss: 0.1682 - accuracy: - ETA: 23s - loss: 0.1683 - accuracy: 0. - ETA: 23s - lo - ETA: 20s - loss: 0.1683 - accuracy:  - ETA: 20s - loss: 0.1684 - accur - ETA: 19s - loss: 0.1683 - accuracy:  - ETA: 18s - loss: 0.1682 - a - ETA: 17s - loss: 0.1683 - accura - ETA: 16s - loss: 0.1683 - accuracy: 0.934 - ETA: 16s - loss: 0.1683 - accuracy: 0.934 - ETA: 16s - loss: 0.1682 - accuracy: 0.934 - ETA: 16s - loss: 0.1683 - accur - ETA: 15s - loss: 0.1684 - a - ETA: 13s - loss: 0.1684 - accuracy: - ETA: 13s - loss: 0.1684 - accuracy: 0. - ETA: 12s - loss: 0.1684 - accuracy: - ETA: 12s - - E - ETA: 4s - loss: 0.1684 - accuracy: 0. - ETA: 4s - l - ETA: 2s - loss: 0.1683 -  - ETA: 1s - loss: 0.1684 - accuracy - ETA: 1s - loss: 0.1684 - accuracy:  - ETA: 1s - loss: 0.1685 - accu - ETA: 0s - loss: 0.1685
# Epoch 10/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1667 - accuracy: 0.9350 - val_loss: 0.1662 - val_accuracy: 0.9368s: 0.1611 - accuracy: 0. - ETA - ETA: 2:00 - loss: 0 - ETA: 1: - ETA: 1:56 - loss: 0.1684 - accu - ETA: 1:55 - ETA: 1:54 - loss: 0.1704 -  - ETA - ETA: 1:51 - loss: 0 - ETA: 1:50 - loss: 0 - ETA: 1:49 - loss: 0 - ETA: 1:48 - loss: 0.1696 - accuracy: 0.93 - ETA: 1:48 - loss: 0.1695 - accuracy: 0.93 - ETA: 1:48 - loss: 0.1693 -  - ETA: 1:47 - loss: 0.1694  - ETA: 1:46 - loss: 0.1687 - accu - ETA: 1:46 - loss: 0.1 - ETA: 1:45 - los - ETA: 1:44 - loss: 0.1683 - accuracy: 0.93 - ETA:  - ETA: 1:40 - loss: 0.168 - ETA: 1:39 - loss: 0.1687 - accuracy - ETA: 1:39 - loss: 0.1687 - accuracy: 0.93 - ETA: 1:39 - loss: 0.1687 - accu - ETA: 1:38 - loss: 0.1691 - accuracy: 0.93 - ETA: 1:38 - loss: - ETA: 1:37 - loss: 0.1688  - ETA: 1:36 - loss: 0.1688 - accura - ETA: 1:36 - loss: 0.1688 - accuracy: 0.93 - ETA: 1:36 - loss: 0.1687 -  - ETA: 1:35 - loss: 0.1 - - ETA: 1:30 - loss: 0.1689 - accuracy:  - ETA: 1:30 - loss: 0.168 - - ETA: 1:21 - loss: 0.1687 - accuracy:  - ETA: 1:21 - loss: 0.1686 - accuracy - ETA: 1:20 - loss: 0.1686 - accuracy:  - ETA: 1:20 - los - ETA - ETA: 1:17 - loss: 0.1688 - accuracy - ETA: 1:17 - loss: 0.1687 - accuracy:  - ETA: 1:17 - loss: 0.1687 - ac - ETA: 1:16 - loss: - ETA: 1:15 - loss: 0.1683 - ac - ETA: 1:14 - loss: 0.1685 - accuracy:  - - ETA: 1:12 - loss: 0.1679 - accu - ETA: 1:12 - loss: 0.1679 - accuracy: 0.93 - ETA: 1:12 - loss: 0.1679 - accu - ETA: 1: - ETA: 1:10 - loss: 0.1678  - ETA: 1:09 - loss: 0.1678  - ETA: 1:08 - loss: 0.1677 - accuracy - ETA: 1:08 - loss: 0.1676 - accuracy - ETA: 1:07 - loss: 0.1676 - accuracy: 0. - ETA: 1:07 - loss: 0.1675 - accuracy:  - ETA: 1:07 - loss: 0.1 - ETA: 1:04 - loss: 0.1677  - ETA: 1:03 - loss: 0.1677 - accuracy: 0.93 - ETA: 1:03 - loss: 0.1677 - accuracy - ETA: 1:03 - l - ETA: 1:01 - loss: 0.1674 -  - ETA: 1:01 - l - ETA: 59s - loss: 0.1674 - - ETA: 57s - loss: 0.1674  - ETA: 56s - loss: 0.1672 - accuracy: 0.934 - ETA: 56s - loss: 0.1672 - accura - ETA: 55s - loss: 0.1673 - accuracy: 0.93 - ETA: 55s - loss: 0.1672 - accu - ETA: 54s - loss: 0.1672 - a - ETA - ETA: 49s - loss - ETA: 47s - loss:  - ETA: 45s - loss: 0.1671 - accuracy - ETA: 44s - loss: 0.1669 - acc - ETA: 43s - loss: 0.1669 - accuracy: 0.9 - ETA: 43s - loss: 0.1669 - accuracy - ETA: 42s - loss: 0.1670 - accurac - ETA: 41s - loss: 0.1669 - accuracy: 0.93 - ETA: 41s - loss:  - ETA: 39s - loss: 0.1671 - accuracy - ETA: 38s - los - ETA: 36s - loss: 0.1674 - accu - ETA: 35s - loss: 0.1672 - accuracy: 0.934 - ETA: 34s - loss: 0.1672 - accuracy: 0 - ETA: 34s - loss: 0.1673 - accuracy: 0.934 - ETA: 34s - loss: 0.1673 - accu - ETA: 33s - loss: 0.1673 - ETA: 31s - loss: 0.1671 - acc - ETA: 30s - loss: 0.1671 - accuracy: 0. - ETA: 30s - loss: 0.1671 - accuracy:  - ETA: 29s - loss: 0.1671 - accuracy: 0.9 - ETA: 29s - loss: 0.1670 - acc - ETA: 28s - loss: 0.1670 - accuracy: 0.9 - ETA: 28s - loss: 0.1670 - - ETA: 26s - loss:  - ETA: 24s  - ETA: 21s -  - ETA: 18s - loss: 0.1668 - a - ETA: 17s - loss: 0.1668 - accuracy: 0.93 - ETA: 17s - loss: 0.1668 - accur - ETA: 16s - loss: 0.1668 - accuracy: 0.93 - ETA: 16s - loss: 0.1668 - accura - ETA: 15s - loss: 0.1667 - ac - ETA: 14s - loss: 0.16 - ETA: 12s - loss: 0.1 - ETA: 10s - loss: 0.1669  - ETA: 9s - l - ETA: 7s - loss: - ETA: 6s - loss: 0.1668 - accuracy - ETA: 6s - loss: 0.1668 - accura - ETA: 4s - loss: 0.166 - ETA: 3s - loss: 0.1667 - accuracy - ETA: 3s - loss: - ETA: 1s - loss: 0.1668 - ac - ETA: 1s -
# Epoch 11/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1653 - accuracy: 0.9356 - val_loss: 0.1795 - val_accuracy: 0.9365: 56s - loss: 0.1662 - acc - ETA: 55s - ETA: 52s - loss: 0.1660 - a - ETA: 51s - loss: 0.1658 - ETA: 49s - loss: 0.1659 -  - ETA: 44s - loss: 0.1656 - accur - ETA: 43s - loss: 0.1658 - accurac - ETA: 42s - loss: 0.16 - ETA: - ETA: 37s - loss: 0.1659 - accuracy: 0.935 - ETA: 37s - ETA: 30s - loss: 0.1657 - accuracy: 0.9 - ETA: 30s - loss: 0.1658 - accuracy - ETA: 29s - loss: 0 - ETA - ETA: 5s - loss: 0.1652 -  - ETA: 4s - loss: 0.165 - E
# Epoch 12/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1638 - accuracy: 0.9362 - val_loss: 0.1621 - val_accuracy: 0.9378 loss: 0.1659 -  - ETA: 1:43 - loss: 0.1659  - ETA: 1:42 - loss: 0.1657 - accuracy: 0.93 - ETA: 1:18 - loss: 0.1653 - accuracy - E - ETA:  - ETA: 1:10 - loss: 0.164 - ETA: 1:09 - loss: 0.1641 - accuracy: 0. - ETA - ETA: 59s - loss: 0.1644 - a - ETA: 58s - loss: 0.1644 - accuracy:  - ETA: 57s - loss: 0.1644 - accu - ETA: 56s - loss: - ETA: 26s - loss: 0.1634 - - ETA: 25 - E - ETA: 0s - loss: 0.1638
# Epoch 13/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1626 - accuracy: 0.9366 - val_loss: 0.1621 - val_accuracy: 0.93808 - ETA: 42s -  - ETA: 39s - loss:  - ETA: 37s - loss: - ETA: 35s - loss: 0.1628 - accur  - ETA: 14s - loss -
# Epoch 14/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1609 - accuracy: 0.9371 - val_loss: 0.1537 - val_accuracy: 0.9404 - ETA: 55s - l  - ETA: 48s - loss: 0.1605 - accur - ETA: 47s - loss: 0.1605 - accuracy - ETA: 47s - loss: 0.1604 - accuracy: - ETA: 34s - loss: 0.1604 - accuracy: 0 - ETA: 34s - loss: 0.1603 - accuracy:  - ETA: 33s - loss: 0.160 - ETA: 24s - loss: 0.1604 - - ETA: 22s - loss: 0.1605 - accurac - ETA: 21s - loss - ETA: 3s - los
# Epoch 15/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1599 - accuracy: 0.9377 - val_loss: 0.1513 - val_accuracy: 0.9415s: 0.1592 - accuracy - ETA: 50s - loss: 0.1592 - accura  - ETA: 42s - loss - ETA: 39s - loss: 0.1596 - accura - ETA: 38s - loss: 0.1596 - accura - ETA: 38s - loss: 0. - ETA: 36s - loss: 0.1596 - accura - ETA: 31s  - ETA: 28s - loss: 0.1598 - - ETA: 26s - loss: 0.1 - ETA: 25s  - ETA: 22s - loss: 0.1599 - accuracy: 0.9 -  - ETA: 4s - loss: 0.1597 - accuracy: 0.93 - ETA: 4s - loss: 0.1597 - accuracy: 0.93 - ETA: 4s - l - ETA: 0s - loss: 0.1
# Epoch 16/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1591 - accuracy: 0.9379 - val_loss: 0.1559 - val_accuracy: 0.9409ETA: 45s - loss: 0.1582 - accura - ETA: 44s - loss: 0.1585  - ETA: 43s - loss: 0.1
# Epoch 17/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1581 - accuracy: 0.9383 - val_loss: 0.1613 - val_accuracy: 0.93725 - ET - ETA: 38s - loss: 0.1577 - accur - ETA: 37s - loss: 0.1575 - accura - ETA: 36s - loss: 0.1575 - accuracy: 0.9 - ETA: 36s - loss: 0.1576 - accuracy - ETA: 35s - ETA: - ETA: 29s - loss: 0.1578 - ETA: 27s - loss: 0.1580 - acc - ETA: 26s - loss: 0.1579 - acc - ETA - ETA: 0s - loss: 0.1581 - accu
# Epoch 18/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1571 - accuracy: 0.9387 - val_loss: 0.1471 - val_accuracy: 0.9432- loss: 0.1578 - ac - E - ETA: 45s - loss: 0.1579 - accura - ETA: 44s - - ETA: 41s - loss: 0.1580 - accuracy: 0.9 - ETA: 41s - loss: 0.1580 - accu - ETA: 28s - loss: 0.1576 - accuracy: 0.93 - ETA: 28s - loss: 0.157 - ETA: 26s - loss: 0.1576 - ac - ETA: 17s - loss: 0.1572 - accuracy: 0.93 - ETA: 17s - loss: 0.1572 - ETA: 1 - E
# Epoch 19/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1568 - accuracy: 0.9387 - val_loss: 0.1533 - val_accuracy: 0.9414: 54s - loss: 0.1565 - accura - ETA: 53s - loss: 0.1564 - ac - ETA: 52s - loss: 0.1566 - accuracy: - ETA: 52s - loss: 0.1567 - - ETA: 50s - loss: 0.1568 - accura - ETA: 49 - ETA:  - ETA: 39s - loss: 0.1569 - accu - - ETA: 26s - loss: 0.1569 - accu - ETA: 25s - loss: 0.1569 - accuracy: - ETA: 25s - loss: 0.1570 - - ETA: 23s - loss: 0.1571 - accu - ETA: 22s - loss: 0.1573 - accura - ETA: 21s - loss: 0.1571 - accuracy: 0.93 - ETA: 21s - loss: 0.1572 - accura -
# Epoch 20/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1557 - accuracy: 0.9392 - val_loss: 0.1628 - val_accuracy: 0.9416 - ETA: 1:01 - los - ETA: 53s - loss:  - ETA: 51s - loss: 0.1561 - accura - ETA: 50s - loss - ETA: 47 - ETA: 44s - loss: 0.15 - ETA: 42s - loss: 0.1 - ETA: 37s - loss: 0.1557 - accuracy: 0.939 - ETA: 36s - loss: 0.1556 - accuracy: - ETA: 36s - loss: 0.1555 - ac - ETA: 35s - loss: 0.1555 - accuracy: 0 - E - ETA: 31s - loss: 0.1558 - accuracy - ETA: 30s - loss: 0.1557 - ETA: 28s -  - ETA: 4s - loss: 0.1558 - accuracy
# Epoch 21/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1551 - accuracy: 0.9393 - val_loss: 0.1473 - val_accuracy: 0.9433- accuracy - ETA: 50s - loss: - ETA: 3 - ETA: 28s - loss: 0.1550 - ETA: 27s - loss: 0.1552 - a - ETA: 22s - loss: 0.1553 - accuracy: 0. - ETA: 21s - loss: 0.1554 - accuracy - ETA: 20s - loss: 0.155 - ET - ETA: 1s - loss: 0.1 - ETA: 0s - loss: 0.1551 - accuracy: 0.93
# Epoch 22/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1546 - accuracy: 0.9396 - val_loss: 0.1507 - val_accuracy: 0.9431 - ETA: 52s - loss: 0.153 - ETA: 51s - loss: - ETA: 48s - loss: 0.1542 - - ETA: 4 - ETA: 44 - ETA: 41s - loss: 0 - ETA: 35s - loss: 0.1 - ETA: 29s - loss: 0.1542 - accuracy: 0.93 - ETA: 28s -  - ETA: 26s - loss: 0.1543 - a - ETA: 24s -  - ETA: 22s - ETA: 19s - loss: 0.154 - ETA: 17s - loss: - ETA: 15s - loss: 0.1543 - accurac - ETA: 14s - loss: 0.1543
# Epoch 23/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1538 - accuracy: 0.9399 - val_loss: 0.1582 - val_accuracy: 0.9368s - loss: 0.15 - ETA: 48s - loss: 0.1538 - - ETA: 46s - loss: 0.1537 - accuracy:  - ETA: 46s - loss: 0.1537 - accuracy - ETA: 45s - lo - ETA: 42s - loss: 0.1534 - accuracy: 0.9 - ETA: 38s - loss: 0.1533 - accuracy - ETA: 38s - loss: 0.1533 - accur - ETA: 37s - loss: 0.1534 - accur  - ETA: 32s - loss: 0.1537 - accuracy: 0.93 - ETA: 32s - ET - ETA: 25s - loss: 0.1539 - ETA: 24s - loss: 0.1538 - accuracy: 0.939 - ETA: 23s - loss: 0.1538 - accu - ETA: 22s - loss: 0. - ETA: 20s - loss: 0.1538 - accuracy: 0.9 - ETA: 20s - loss: 0.1538 - ac - ETA - ETA: 15s - loss: 0.1539 - accur - ETA: 14s - loss: 0.1539 - accuracy: 0.9 - ETA: 14s - loss: 0.1539 - accurac - ETA: 13s - loss: 0.1539 - ac - ETA: 12s - loss: 0.1539 - accuracy:  - ETA: 12s - loss: 0.1539 - accuracy: 0.93 - ETA: 12s - loss: 0.1539 -  - ETA: 6s - loss: 0.1537 - accura - ETA: 5s - loss: 0.1537 - accuracy: 0. - ETA: 5s - loss: 0.1538 - ac - ETA: 5s - loss: 0.1537 - accuracy: 0. - E - ETA: 3s - los - ETA: 1s - loss: 0.1538 - accuracy:  - ETA: 1s - loss: 0.1538 - accu - ETA: 1s - loss: 0.1538  - ETA: 0s - loss: 0.1537 - accuracy: 0.93 - ETA: 0s - loss: 0.1537 - accuracy
# Epoch 24/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1535 - accuracy: 0.9399 - val_loss: 0.1445 - val_accuracy: 0.94445 - accuracy: 0.94 - E - - ETA: 1:47 - - ETA - ETA: 1:41 - loss: 0.1526 - accuracy: 0.94 - ETA: 1:40 - loss: 0.1526 - accuracy:  - ETA: 1:40 - loss: 0.1526 -  - ETA: 1:40 - los - ETA - ETA: 1:37 - loss: 0.1518  - ETA: 1:36 - los - ETA: 1:35 - loss: 0.1522 - accuracy: 0.94 - ETA: 1:35 - loss: 0.1521 -  - ETA: 1:34 - loss: 0.1523 - accuracy: 0.94 - ETA: 1:34 - loss: 0.1523 - accura - ETA: 1:33 - loss: - ETA: 1: - ETA: 1:31 - loss: 0.1521 -  - ETA: 1:30 - loss: 0.1521 - accuracy: 0.94 - ETA: 1:30 - loss: 0.1523 - accuracy:  - ETA: 1:23 - loss: 0.1 - ETA: 1:23 - - ETA: 1:21 - loss: 0 - ETA: 1:18 - loss: 0.1519 - ac - ETA: 1:18 - los - ETA: 1:16 - loss: 0.1518  - ETA: 1:16 - loss: 0.1519 - accuracy: 0. - ETA: 1:15 - loss: 0.1519 - accu - ETA: 1:15 - loss: 0.1520 -  - ETA: 1:14 - loss: 0.1521  - ETA: 1:07 - - ETA: 1:06 - loss: 0.1530 - accuracy: 0. - ETA: 1: - ETA: 1:04 - loss: 0.1533 - accura - ETA: 1:04 - loss: 0.1 - ETA: 1:03 - loss: 0.1533 - accuracy: 0.94 - ETA: 1:03 - loss: 0.1534 - accuracy - ETA - ETA: 1:01 - loss: 0.1536  - ETA: 1:00 -  - ETA: 53s - loss: 0.1537 - accuracy: 0.93 - ETA: 53s - loss: 0.1537 - accuracy: - ETA: 52s - loss: 0.1537 - accuracy: 0.93 - ETA: 52s - loss: 0.1536 - accu - ETA: 51s - loss: 0.1536 - accuracy - ETA: 51s - loss: 0.1535 - accuracy: 0.93 - ETA: 50s - loss: - ETA: 48s - loss: 0.1534 - accuracy - ETA: 47s - loss: 0.1537 - accurac - ETA: 47s - loss: 0.1536 - - E - ETA: 38s - loss: 0.1538 - accuracy - ETA: 37s - loss:  - ETA: 35s - loss: 0.1539 - accuracy: 0.9 - ETA: 34s - loss - ETA: 32s - loss: 0.1542 - accur - ETA: 31s - loss: 0.1541  - ETA: 30s - loss: 0.1542 - accuracy - ETA: 29s - loss: 0.1542 - accuracy - ETA: 28s - loss: 0.1542  - ETA: - ETA: 23s - loss: 0.1540 - accuracy: 0.939 - ETA: 23s - loss: 0.1540 - accur - ETA: 22s - loss: 0.1539 - ETA: 21s - loss: 0.1538 - accuracy: 0 - ETA: 20s - loss: 0.1539 - ac - ETA: 19s - loss: 0.1539 - ETA: 17s - loss: 0.1538 - accuracy: 0.939 - ETA: 17s  - ETA: 14s - loss:  - ETA: 12s - loss: 0.1538 - ETA: 10s - loss: 0.1537  - ETA: 2s - loss: 0.1535  - ETA: 1s -
# Epoch 25/50
# 82800/82800 [==============================] - 144s 2ms/sample - loss: 0.1526 - accuracy: 0.9403 - val_loss: 0.1486 - val_accuracy: 0.9418 0.1516 - accuracy:  - ETA: 1:56 - loss: 0.1516 - accuracy - ETA:  - ETA: 1:44 - loss: 0.1541 - accuracy - ETA: 1:44 - loss: 0.1545 - accu - ETA:  - ETA: 1:15 - loss: 0 - ETA: 1:14 - loss: 0.1538 - accuracy: 0.93 - ETA:  - ETA: 1:13 - loss: 0.1 - ETA: 1:12 - loss: 0.1536 - ac - ETA: 1:11 - loss: 0.1537 -  - ETA: 1:10 - loss: 0 - ETA: 1:09 - loss: 0 - ETA: 1:08 - los - ETA: 1:07 - loss: 0.1535  - ETA: 1:06 - loss: 0.1533 - accuracy:   - ETA: 53s - loss: 0.1533 - accur - ETA: 52s - los - ETA: 45s - loss: 0.1531 - accuracy: 0.9 - ETA: 45s - l - ETA: 43s - loss: 0.1535 - accuracy: 0.940 - ETA: 42s - loss: 0.1535 - accuracy: 0.940 - ETA: 42s - loss: 0.1535 - accuracy: 0.94 - ETA: 42s - loss: 0.1535 - accuracy: 0.93 - ETA: 42s - loss: 0.1535 - accurac -  - ETA: 38s - loss: 0.153 - ETA: 36s - - ETA: 34s - loss: 0.1531 - accuracy:  - ETA: 29s - loss: 0.152 - ETA: 28s - loss: 0.15 - ETA: 26s - loss: 0.1529 - accuracy: 0.9 - ETA: 25s - loss: 0.1529 - accur - ETA: 24s - loss: 0.1 - ETA: 22s - loss: 0.1529 - accura - ETA: 22s - loss: 0.1529 - accura - ETA: 21s - loss: 0.1528 - accuracy: 0.940 - ETA: 21s - loss: 0.1528 -  - ETA: 19s - l - ETA: 17s - loss: 0.1528 -  - ETA: 15s - loss: 0.1528 - acc - ETA: 14s - loss: 0.1528  - ETA: 12s - loss: 0.1530 - accur - ETA: 11s - lo - ETA: 9s - loss: 0.1530 - ac - ETA: 9s - loss: - ETA: 7s - loss: 0.1530 - accuracy - ETA: 7s - loss: 0.1530 - accu - ETA: 7s - loss: 0.1530 - accuracy: 0. - ETA: 6s - loss: 0.1530 - accuracy: 0.94 - ETA: 6s - loss: 0.1530 - accuracy:  - ETA: 6s - loss: 0.152
# Epoch 26/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1522 - accuracy: 0.9406 - val_loss: 0.1479 - val_accuracy: 0.94132:01 - loss: 0.1535 -  - ETA: 2:00 - loss: 0.1496 - ac - ETA: 1:59 - loss: 0.1499 - ac - ETA: 1:59 - loss: 0.1526 -  - ETA: 1:58 - loss: 0.1526 - accuracy: 0.93 - ETA: 1:58 - loss: 0.1531 - accuracy: 0. - ETA: 1:58 - los - - - ETA: 1:40 - loss: 0.150 - ETA: 1:36 - loss: 0.1504 - accuracy:  - ETA - ETA: 1:34 - loss: - ETA: 1:32 - loss: - ETA: 1:31 - ETA: 1:24 - ETA: 1:22 - loss: 0 - ETA: 1:19 - loss: 0.1515  - E - ETA: 1:17 - los - ETA: 1:13 - loss: 0.1516 - accuracy: 0. - ETA: 1:13 - ETA: 1:12 - loss: 0.1 - - ETA: 1:09 - loss: 0.1520 - accuracy: 0.94 - ETA: 1:09 - loss: 0.1520 - accu - ETA: 1:08 - loss: 0.1519 - accuracy: 0. - ETA: 1:08 - loss: 0.1518 - accura - ETA: 1:08 - loss: 0.1518 - accuracy:  - ETA: 1:07 - loss: 0.1518 - accuracy: 0.94 - ETA: 1:07 - loss: 0.1518 - accuracy: 0.94 - ETA: 1:07 - loss: 0.1 - ETA: 1:06 - loss: 0.1519  - ETA: 1:05 - loss: 0.1521 - accuracy: 0. - - ETA: 1:03 - los - ETA: 1:02 - loss: - ETA: 1:01 - loss: 0.1521 - accura - ETA:  - ETA: 59s - loss: 0.1522 - accuracy: 0.94 - ETA: 58s - loss: 0.15 - ETA: 57s - loss: 0.1519 - accuracy: 0. - ETA: 56s - loss: 0.1520 - accuracy: 0.9 - ETA: 56s - loss: 0.1520 - accuracy: 0. - ETA: 56s - loss: 0.1519 - a - ETA: 54s - - ETA: 52s - loss: 0.152 - ETA: 50s - loss:  - ETA: 48s - loss: 0.1524 - accuracy:  - ETA: 47s - loss: 0.1524 - accura - ETA: 46s - loss: 0.1525 - ETA: 45s - loss: 0.1526 - accuracy: 0.940 - ETA: 45s - loss: 0.1526 - accu - ETA: 43s - loss: 0.1527 - accuracy: 0.940 - ETA: 43s - loss: 0.1527 - accuracy: 0.940 - ETA: - ETA: 40s - loss: 0.1525 - accuracy: 0.9 - ETA: 40s - loss: 0.1525 - accuracy: 0. - ETA: 39s - loss: 0.1525 - accura - ETA: 38s - loss: 0.1525 - accuracy - ETA: 38s - loss: 0.1525 - accuracy: 0.94 - ETA: 38s - loss: 0.1525 - accuracy: 0.940 - ETA: 37s - loss: 0.1525 - accuracy: 0.940 - ETA: 37s - loss: 0.1525 - accuracy: 0.940 - ETA: 37s - loss: 0.1524 - accur - ETA: 36s - loss: 0.1525 - accuracy: 0 - ETA: 36s - loss: 0.1525 - ac - ETA: 35s -  - ETA: 32s - loss: 0.1527 - accuracy: 0.940 - ETA: 32s - loss: 0.1527 -   - ETA: 26s - loss: 0 - ETA: 24s - loss: 0.1524 - accuracy: 0.940 - ETA: 24s - loss: 0.1524 - accura - ETA: 23s - loss: 0.1524 - accuracy: 0.940 - ETA: 23s - loss: 0.1525 - accuracy: 0.94 - ETA: 23s - loss: 0.1524 - accu - ETA: 22s - loss: 0.1524 - accuracy: 0. - ETA: 22s - loss: 0.1524 - accuracy: 0. - ETA: 21s - loss: 0.1523 - a - ETA: 20s - loss: 0.1 - ETA: 18s - loss: 0.1524 - accur - ETA: 17s - loss: 0.1525 - accuracy:  - ETA: 17s - loss: 0.1525 - accuracy: 0.94 - ETA: 17s - loss: 0.1526 - a - ETA: 15s - loss: 0.1524 - accu - ETA: 14s - loss: 0.1524 - ETA: 12s -  - ETA: 10s - loss: 0.1524 - accuracy: 0 - ETA: 9s - loss: 0.1524 - accuracy: 0. - ETA: 9s - loss: 0.1524  - ETA: 8s - loss: 0.1523 - accuracy: 0. - ETA: 8s - loss: 0.1523  - ETA: 6s - - ETA: 4s - loss: 0.1522 -  - ETA: 3s - loss: 0.1521 - accuracy:  - ETA: 3s - ETA: 2s - loss: 0.1522 - accu - ETA: 1s - loss: 0.1521 - ac - ETA: 1s - los
# Epoch 27/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1517 - accuracy: 0.9406 - val_loss: 0.1429 - val_accuracy: 0.9445 - loss: 0.1502 - accuracy: 0.94 - ETA: 1:51 - loss: 0.1500 - accura - ETA: 1:50 - loss: 0.1502 - accu - ETA: 1:50 - loss: 0.1499 -  - ETA: 1:49 - loss: 0.1498 - accuracy: 0.94 - ETA: 1:49 - loss: 0.1499 - accuracy: 0. - ETA - ETA: 1:47 - loss: 0.1517 - accuracy: 0. - ETA: 1:47 - loss: - ETA: 1:46 - loss: 0.1513 - accuracy: 0. - ETA: 1:38 - loss: 0.1523 - ac - ETA: 1:37 - loss: - ETA: 1:36 - loss: 0.1523 - accuracy: 0. - ETA: 1:36 - loss: 0.1522 - accuracy: 0.94 - ETA: 1:36 - loss: 0.1521 - ac - ETA: 1:31 - loss: 0.151 - ETA: 1:30 - loss: 0.1516 - accuracy:  - ETA: 1:30 - loss: 0.1517 - accura - ETA: 1:30 - loss: 0.1516 - accuracy - ETA: 1:29 - loss: 0.1517 - accuracy: 0. - ETA: 1:29 - loss: 0.1517 - accuracy: 0. - ETA: 1:29 - loss: 0.1516 -  - ETA: 1:22 - loss: 0.1517 - accuracy:  - ETA: 1:22 - loss: 0.1516 - accu - ETA: 1:21 - loss: 0.1514 - accura - ETA: 1:13 - loss: 0 - ETA: 1:12 - loss: 0.1521 - ac - ETA: 1:11 - loss: 0.1520  - ETA: 1:10 - loss: 0 - ETA: 1:01 - loss: 0.1513 - accuracy: 0. - ETA: 1:01 - loss: 0.1513  - ETA: 1:00 - loss: 0.1514 - ETA: 59s - loss: 0.1514 - accur - ETA: 58s - loss: 0.1512 - accuracy: 0 - ETA: 57s - loss: 0.1513  - ETA: 56s - loss: 0.1512 - accuracy: 0. - ETA: 55s - loss: 0.1512 - accuracy: 0.940 - ETA: 55s - loss: 0.1513 - accuracy: 0. - ETA: 55s - loss: 0.1513 - accur - ETA: 54s - loss: 0.1512 - accuracy:  - ETA: 54s - loss: 0.1513 - accuracy: 0. - ETA: 53s - loss: 0.1514 - accur - ETA: - ETA: 45s -  - ETA: 42s - loss: - ETA: 40s - loss: 0.1515 - ac - ETA: 39s - loss: 0.1515 - accuracy: 0 - ETA: 38s - loss: 0.1514 - accur - ETA: 37s - loss: 0.1513 - - ETA: 36s - loss: 0.1512 - accuracy: 0 - ETA: 36s - loss: 0.1513 - - ETA: 34s - loss: 0.1513 - a - ETA: 33s - loss: 0.1513 - accur - ETA: 32s - loss: 0.1513 - accurac - ETA: 31s - loss: 0 - ETA: 29s - loss: 0.1514 - accu - ETA: 28s - loss: 0.1514 - accura - ETA: 27s - loss: 0.1512 - accuracy: - ETA: 26s - loss: 0.1512 - - ETA: 25s - loss: 0.1513 - accuracy: 0.940 - ETA: 25s - loss: 0.1513 - accuracy:  - ET - ETA: 21s - loss: 0.1514 - accuracy - ETA: 20s - loss: 0.1514 - accurac - ETA: 19s - loss: 0.1514 - accuracy: 0.9 - ETA: 19s - loss: 0.1514 - accuracy: 0.940 - ETA: 19s - loss: 0.1514 - - ETA: 17s - loss: 0.1516 - accuracy: 0. - ETA: 17s - loss: 0.1516 - accu - ETA: 16s - loss: 0.1517 - accuracy: 0. - ETA: 16s - loss: 0.1517 - accuracy: 0. - ETA: 15s - loss: 0.1517 -  - ETA: 14s - loss: 0.1517 - accurac - ETA: 13s - loss: 0.1516 - accuracy: 0.940 - ETA: 13s - loss: 0.1516 - accu - ETA: 12s - loss: 0.1518 - accuracy: 0 - ETA: 12s - loss: 0.1518 - accuracy: 0.940 - ETA: 11s - loss: 0.1518 - accuracy: 0. - ETA: 11s  - - ETA: 7s - loss: 0.1517 - accuracy:  - ETA: 7s - loss: 0.1518 -  - ETA: 6s - loss: 0.1 - ETA: 5s - loss: 0.1 - ETA: 4s - loss: 0.1518 - accuracy: 0. - ETA: 4s - loss: 0.1517 - accuracy: 0.94 - ETA:  - ETA: 2s - loss: 0.1517 - accuracy: 0.94 - ETA: 2s - loss: 0.1517 -  - ETA: 1s - loss: 0.1517 - ac - ETA: 1s - loss: 0.1518 - accuracy: 0.94 - ETA: 1s - loss: 0.1517 - accura - ETA: 0s - loss: 0.1517 - accuracy: 0. - ETA: 0s - loss: 0.1517 -
# Epoch 28/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1515 - accuracy: 0.9407 - val_loss: 0.1517 - val_accuracy: 0.9424468 - accuracy: 0.94 - ETA: 2:01 - loss: 0.1469  - ETA: 1:48 - loss: 0.1481 - accuracy:  - ETA: 1:48 - loss: 0.148 - ETA: 1:47 - loss: 0.1487 - accuracy: 0. - ETA - ETA: 1:45 - loss: 0.1487 - accuracy: 0.94 - ETA: 1:45 - loss: 0 - ETA: 1:44 - los - ETA: 1: - ETA: 1:41 - loss: 0 - ETA: 1:40 - loss: 0.1498 -  - ETA: 1:39 - loss: 0.1499 - accuracy: 0. - ETA: 1:39 - loss: 0.1500 - accuracy: 0.94 - ETA: 1:39 - loss: 0.1 - ETA: 1:38 - los - ETA: 1:37 - loss: 0.1495 -  - ETA: 1:36 - loss: 0.1493 - accuracy - ETA: 1:36 - loss: 0.1496 - accuracy: 0.94 - ETA: 1:36 - loss: 0.1497 - accura - ETA: 1:35 - los - ETA: 1:34 - loss: 0.1493 -  - ETA: 1:33 - loss: 0.1492 - accura - ETA: 1:33 - l - ETA: 1:21 - loss: 0.1494 - accuracy:  - ETA: 1:21 - loss: 0 - ETA: 1:20 - loss: 0.1496 - accuracy:  - ETA: 1:20 - loss: 0.1496 - accuracy: 0. - ETA: 1:18 - loss: 0.1494 -  - ETA: 1:17 - los - ETA: 1:16 - loss: 0.1497 -  - ETA: 1:15 - loss: 0.1496 - ac - ETA: 1: - ETA: 1:07 - loss: 0.1510 - accuracy: 0.94 - ETA:  - ETA: 1:05 - loss: 0.1511 - accuracy: 0. - - ETA: 1:03 - loss: 0.1512 - accuracy: 0.94 - ETA: 1:03 - los - ETA: 1:00 -  - ETA: 57s - loss: 0.1510 - - ETA: 56s - loss: 0.1511 - accuracy - ETA: 55s - loss: 0.1514 - accuracy - ETA: 54s - loss: 0.1514 - accuracy: 0.940 - ETA: 54s - loss: 0.1515 - accura - ETA: 53s - loss: 0 - ETA: 51 - ETA: 48s - loss: 0.1518 - accuracy: 0.9 - ETA: 48s - l - ETA: 45s - loss: 0.1517 - acc - ETA: 44s - loss: 0.1516 - accuracy: 0.94 - ETA: 44s - loss: 0.1517 - accu - ETA: 39s - loss: 0.1519 - accuracy: 0.9 - ETA: 39s - loss: 0.1520 - accurac - ETA: 38s - loss: 0.1520 - accuracy:  - ETA: 37s - loss: 0.1519 - accuracy - ETA: 37s - loss: 0.1520 - accu - ETA: 35s - loss: 0.1520  - ETA: 34s - loss: 0.1521 - accuracy: 0 - ETA: 33s - loss: 0.1520 - accuracy: 0. - ETA: 33s - loss: 0.1519 - accuracy:  - ETA: 32s - loss: 0.1519 - accuracy:   - ETA: 28s - loss: 0.1518 - accuracy:  - ETA: 28s - loss: 0.1518 - accuracy: 0 - ETA: 27s - loss:  - ETA: 25s - loss: 0.1519 - ac - ETA: 24s - loss: 0.1519 - accur - ETA: 23s - loss: 0.1519 - accuracy: 0.9 - ETA: 22s - loss: 0.1518 - accuracy - ETA: 22s  - ETA - ETA: 15s - loss: 0.1520 - accura - ETA: 15s - loss: 0.1519 - accuracy: 0 - ETA: 14s - loss: 0.1519 - accuracy: 0.9 - ETA: 14s - loss: 0.1519 - accurac - ETA: 13s - loss: 0.1518 - accuracy:  - ETA: 13s - loss: 0.1 - ETA: 11s - loss: 0.1519 - accuracy: 0.94 - ETA: 10s - loss: 0.15 - ETA: 9s - los - ETA: 8s - loss: 0.1516 - accuracy: 0.94 - ETA: 8s - loss: 0.1516 - accuracy - ETA: 5s - loss: 0.1 - ETA: 4s - loss: 0.1516 -  - ETA: 4s - loss: 0.1516 - accuracy: 0.94 - ETA: 2s - loss: 0.1515 - accuracy:  - ETA: 2s - loss: 0.151 - ETA: 1s - los
# Epoch 29/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1511 - accuracy: 0.9409 - val_loss: 0.1447 - val_accuracy: 0.943444 - loss: 0.1497 - accura - ETA: 1:43 - loss: 0.1495 - accuracy: 0. - ETA: 1:43 - loss: 0.1492 - accuracy: 0. - ETA: 1:43 - loss: 0.1492 - accuracy: 0. - ETA: 1:43 - loss: 0.1492  - ETA: 1:42 - loss: 0.1493 - accuracy: 0.94 - ETA:  - ETA: 1:36 - loss: 0.1508 - accuracy - ETA: 1:36 - loss: 0.1 - ETA: 1:35 - loss: - ETA: 1:33 - ETA: 1:32 - loss: 0.1499 - accuracy:  - ETA: 1:32 - loss: - ETA: 1:30 - loss: 0.1498 - accuracy: 0.94 - ETA: 1:30 - loss: 0.1498 - ac - ETA: 1:30 - loss: 0 - ETA: 1:29 - loss: 0.1503 - accuracy: 0.94 - ETA: 1:29 - loss: - ETA: 1:27 - loss: 0.1503 - accuracy: 0. - ETA: 1: - ETA: 1:26 - loss: 0.1506 - accuracy - ETA: 1:25 - loss: 0.1505 - accu - ETA: 1:25 - loss: 0.1506 - accuracy - - ETA: 1:22 - loss: 0.1504 - accuracy:  - ETA:  - ETA: 1:21 - los - ETA: 1:19 - loss: 0.1508 - accuracy: 0.94 - ETA: 1:19 - l - ETA: 1:14 - loss: 0.1509 - ac - ETA: 1:13 - loss: 0.1509 - accuracy: 0.94 - ETA: 1:13 - loss: 0.1508 - accura - ETA: 1: - ETA: 1:11 - loss: 0.151 - ETA: 1:10 - loss: 0 - E - ETA: 1:03 - loss: 0.1512 - accuracy: 0. - ETA: 1:03 - loss: 0.1512 - ac - ETA: 1:03 - loss: 0.1512 - accuracy: 0.94 - ETA: 1:03 - loss: 0.1512 - accuracy - ETA: 1:02 - loss: 0 - ETA: 1:01 - loss: 0.1513 - accu - ETA - ETA: 58s - loss: 0.1510 - acc - ETA: 57s - loss: 0.1511  - ETA: 55s - loss: 0.1510 - accuracy: 0.94 - ETA: 55s - loss: 0.1510  - ETA: 54s - loss: 0.1512 - accurac - ETA: 53s - loss: 0.15 - ETA: 51s - loss: 0.1511 - accurac - ETA: 50s - loss: 0. - ETA: 48s - loss: 0.1510 - ac - ETA: 47s - loss: 0.151 - ETA: 45s - loss: 0.1510 - accuracy: 0.94 - ETA: 45s - loss: 0.1510 - accuracy:  - ETA: 45s - loss: 0.1511 - ac - ETA: 43s - loss: 0.1512 - accu - ETA: 42s - loss: 0.1511 - accuracy: 0.9 - ETA: 42s - loss: 0.1511 -  - ETA: 41s - loss: 0.1511 - accuracy: 0.940 - ETA: 41s - loss: 0.1511 - accuracy:  - ETA: 40s - loss: 0.1512 - ETA: 38s - loss: 0.1514 - a - ETA: 37s - loss: 0.1514 - accura - ETA: 36s - loss: 0.1514 - accuracy: 0.940 - ETA: 36s - loss: 0.1514 - accuracy:  - ETA: 36s - loss: 0.1515 - ac - ETA: 34s - loss: 0. - ETA: 32s - loss: 0.1513 - accuracy:  - ETA: 32s - loss: 0.1514 - accuracy - ETA: 31s - loss: 0.1514 - accuracy: 0. - ETA: 31s - loss: 0.1513  - ETA: 29s - loss: 0.1511 - accuracy: 0 - ETA: 29s - loss: 0.1511 - accuracy: 0. - ETA:  - ETA: 25s - loss: 0.1512 - accuracy: - ETA: 25s - loss: 0.1512 - accuracy: 0. - ETA: 24s - loss: 0.1511 - accuracy: 0.94 - E - ETA: 17s - loss: 0.1513 - accuracy: 0. - ETA: 16s - loss: 0.1513 - accuracy: 0.940 - ETA: 16s -  - ETA: 14s - loss: 0.1514 - acc - ETA: 12s - loss: 0.1513 - accuracy: 0.94 - ETA: 12s - loss: 0.1513 - accuracy: 0 - ETA: 12s - loss: 0.1513 - accuracy: 0.9 - ETA: 12s - loss: 0.1513 - accuracy: 0.9 - ETA: 11s - loss: 0.1513 - accuracy: 0 - ETA: 11s - loss: 0.1514  - ETA: 9s - loss: 0.1513 - accuracy: 0.94 - ETA: 9s - loss: - ETA: 8s - loss: 0.1512 -  - ETA: 7s - loss: 0.1512 - accuracy - ETA: 3s - loss: 0.1513 - accura - ETA - ETA: 1s - loss: 0 - ETA: 0s - loss: 0.1511 - ac
# Epoch 30/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1503 - accuracy: 0.9411 - val_loss: 0.1449 - val_accuracy: 0.9423oss: 0.1524 - accuracy:  - ETA: 2:00 - loss: 0.1515 - accuracy: 0.94 - ETA: 2:00 - loss: 0.1513 - accuracy: 0.94 - ETA: 1:59 - loss: 0.1514 - accuracy: 0.94 - ETA: 1:59 - loss: 0.1522 - accu - ETA: 1:55 - l - ETA: 1:49 - loss: 0.1 - ETA: 1:38 - loss: 0 - ETA: 1:29 - loss: 0.150 - ETA: 1:28 - loss: - - ETA: 1:26 - loss: 0 - ETA: 1:22 - loss: 0.149 - ETA: 1:22 - loss: 0.1500 - accuracy: 0. - ETA: 1:21 - loss: 0.149 - ETA: 1:21 - loss: 0.1 - ETA: 1:20 - loss: 0.1498 - accuracy: 0. - ETA: 1:19 - loss: 0.1 - ETA: 1:16 - loss: 0.1500 -  - ETA: 1:16 - loss: 0.1 - ETA: 1:15 - l - ETA: 1:09 - loss: 0.1496 - accuracy: 0. - ETA: 1:09 - loss: 0.1 - ETA: 1:08 - loss: 0.1496 - accuracy: 0. - ETA: 1: - ETA: 1:02 - loss: 0.150 - ETA: 1:02 - loss: 0.1501 - ac - ETA: 1:01 - loss: 0.1 - ETA: 1:00 - loss - ETA: 58s - loss: 0.1501 - acc - ETA: 57s - loss: 0.1500 - accuracy: - ETA: 56s - loss: 0.1499 - accuracy: 0.94 - - ETA: 49s - loss: 0.1503 - accu - ETA: 47s - loss: 0.1503 - accu - ETA: 46s - loss: 0.1502 - accuracy: 0.94 - ETA: 46s - loss: 0.1502 - accuracy: 0.941 - ETA: 46s - loss: 0.1502 - accuracy - ETA: 46s - loss: 0.1501 - accuracy:  - ETA: 45s - loss: 0. - ETA: 39s - loss: 0.1501 - accurac - ETA: 38s - loss: 0.1501 - accuracy - ETA: 38s - loss: 0.1502 - accuracy: - ETA: 37s - loss: 0.1501 -  - ETA - ETA: 32s - loss: 0.1504 - accuracy - ETA: 31s - loss: 0.1505 - accuracy: 0 - ETA: 31s - loss: 0.1504 - accuracy: 0. - ETA: 31s - loss: 0.1504 - - ETA: 29s - loss: 0.1503 - accur - ETA: 28s - loss: 0.1503 - accuracy: 0.94 - ETA: 2 - ETA: 25s - lo - ETA: 22s - loss: 0.1503 - accuracy: 0.941 - ETA: 22s - loss: 0.1503 - ac - ETA: 21s - loss: 0.1503 - accur - ETA: 20s - loss: 0.1503 - ac - ETA: 19s - loss: 0.1503 - accur - ETA: 18s - loss: 0.15 - ETA: 16s - loss: 0.1504 - accuracy: 0.941 - ETA: 16s - loss: 0.1504 - acc - ETA: 15s - loss: 0.1504 - accuracy: 0. - ETA: 15s - loss: 0.1504 -  - ETA: 13s - loss: 0.1504 - accura - ETA: 12s - loss: 0.1504 - accuracy: 0.941 - ETA: 12s - loss: 0.1503 - accuracy: 0.941 - ETA: 12s - loss: 0.1503 - accuracy: 0.941 - ETA: 12s - loss: 0 - ETA: 10s - loss: 0.1505 - accurac - ETA: 9s - loss: 0.1506 - accuracy - E - ETA: 3s - loss: 0.1503 - accuracy: 0. - ETA: 3s - loss: 0.1504 -  - ETA: 2s - loss: 0.1504 - accuracy: 0.94 - ETA: 2s - los - ETA:
# Epoch 31/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1502 - accuracy: 0.9413 - val_loss: 0.1407 - val_accuracy: 0.9454475 - accuracy - ETA:  - ETA: 1:47 - los - ETA: 1:44 - loss: 0.1485 - accura - - ETA: 1: - ETA - ETA: 1:34 - loss: 0.1 - ETA:  - ETA: 1:31 - loss: 0.1486 - accuracy:  - ETA: 1:31 - loss: - ETA: 1:30 - loss: 0.1483 - accuracy: 0.94 - ETA - ETA - ETA: 1:24 - ETA: 1: - ETA: 1:21 - loss: 0.1488 - accu - ETA:  - ETA: 1:17 - loss: 0.1489 - accuracy: 0.94 - ETA: 1:17 - loss: - ETA: 1:16 - loss: 0.1 - ETA: 1:11 - loss: 0.1490 - accuracy: 0. - ETA: 1:11 - loss: 0.1490 -  - ETA - ETA: 1:08 - loss: 0.1489 - accu - ETA: 1:08 - loss: 0.149 - ETA: 1:03 - loss: 0.1494 -  - ETA: 1:02 - loss: 0.1493 - accuracy: 0. - ETA: 1:02 - loss: 0.1492 - accu - ETA: 1:01 - loss: 0.1494 - accuracy: 0.94 - ETA: 1:01 - loss: - ETA: 1:00 - loss: 0.1492 - accuracy: 0.94 - ETA: 1:00 - loss: 0.1492 - accuracy: 0. - ETA: 1:00 - loss:  - ETA: 58s - loss: 0. - ETA: 56s - loss: 0.1496 - accuracy: 0.94 - ETA: 56s - loss: 0. - ETA: 54s - loss: 0.1499 - accurac - ETA: 53s - loss: 0. - ETA: 51s - loss: 0.1502 - accuracy: 0.94 - ETA: 51s - loss: 0.1502 - accuracy: 0.94 - ETA: 51s  - ETA: 48s - loss: 0.1504 - acc - ETA: 47s - loss: 0.1504 - accuracy - ETA: 46s - loss: 0.1505 - accur - ETA: 45s - loss: 0. - ETA: 43s - loss: 0.1505  - ETA: 41s - loss: 0.1504 - accuracy: 0 - ETA: 41s - loss: 0.1504 -  - ETA: 40s - loss: 0.1504 - ETA: 38s - loss: 0.1504 - accuracy: 0. - ETA: 38s - loss: 0.1504 - accuracy:  - ETA: 37s - loss: 0.1504 - accuracy: 0.941 - ETA: 37s - los - ETA: 35s - loss: 0.1504 - acc - ETA: 34s - loss - ETA: 31s - loss: 0.1 - ETA: 29s - loss: 0.1500 - accuracy: 0.941 - ETA: 29s - loss: 0.1501 - accuracy: 0 - ETA: 29s - loss: 0.1500 - accuracy: 0 - ETA: 28s - loss: 0.1501 - accuracy: 0.9 - ETA: 28s - loss: 0.1500 - acc  - ETA: 23s - loss: 0.1503 - accu - ETA: 22s - loss: 0.1503 - accuracy: 0.94 - ETA: 22s - loss: 0.1503 - accuracy: 0 - ETA: 21s - loss: 0.1504 - accuracy:  - ETA: 21s - loss: 0 - ETA: 19s - loss: 0.1505  - ETA: 17s - loss: 0.1504 - accurac - ETA: 16s - lo - ETA: 14s - loss: 0.1505 - accuracy:  - ETA: 13s - loss: 0.1504 - accuracy: 0 - ETA: 13s - loss: 0.1504 - accuracy: 0 - ETA: 12s - loss: 0.1504 - accuracy: 0.9 - ETA: 12
# Epoch 32/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1498 - accuracy: 0.9413 - val_loss: 0.1422 - val_accuracy: 0.9444: 2:00 - loss: 0.1521 - accuracy: 0.94 - ETA: 2:00 - loss: 0.1510 - accuracy - ETA: 1:59 - ETA: 1:52 - loss: 0.1484 - accuracy: 0. - ETA: 1:52 - loss: 0.1478 - accuracy - ETA: 1:51 - loss: 0.1479 - accuracy: 0. - ETA: 1:51 - loss: 0.147 - ETA: 1:50 - l - ETA: 1:49 - loss: 0.148 - ETA: 1:48 - loss: 0.1483 -  - ETA: 1:48 - loss: 0.1493 - accuracy:  - ETA: 1:45 - loss: 0.1487 - accuracy:  - ETA:  - ETA: 1:43 - loss: 0.1 - ETA: 1:40 - loss: 0.1487 - accuracy - ETA: 1:40 - loss: 0.1484 - accuracy: 0. - ETA: 1:40 - loss: 0 - ETA: 1: - ETA: 1:37 - - - ETA: 1:24 - loss: 0.1491 - accuracy: 0.94 - ETA - ETA: 1:22 - loss: 0.1493 - ac - ETA: 1: - ETA: 1:20 - loss: - ETA: 1:19 - loss: 0.1493 -  - ETA: 1:18 - loss: 0.1493 - accuracy: 0. - ETA: 1:18 - loss: 0.1493 - accu - ETA: 1:17 - loss: 0.1493 - accuracy:  - ETA: 1:17 - loss: 0.1492 - accuracy: 0.94 - ETA: 1:17 - loss: 0.1492 - accuracy: 0. - ETA - ETA: 1:15 - loss: 0.148 - ETA: 1:14 - loss: 0.1489 - accu - ETA:  - ETA: 1:12 - los - ETA: 1:11 - loss: 0.1493  - ETA: 1:10 - loss: 0.1494 -  - ETA: 1:09 - loss: 0 - ETA: 1:08 - los - ETA: 1:07 - loss: 0.1492 - ac - ETA: 1:06 - loss: 0.1491 - accu - ETA: 1:06 - loss: - ETA: 1:05 - loss: 0 - ETA: 1:04 - loss: 0.1 - - ETA: 1:01 - loss: 0.1497 - accuracy: 0.94 - ETA: 1:01 - - ETA: 59s - loss: 0.1500 - accuracy: 0.94 - ETA: 59s  - ETA: 56s - loss: 0.1498 - acc - ETA: 55s - loss: 0.1500 - accuracy: 0.941 - ETA: 55s - loss: 0.14 - ETA: 53s - loss: 0.1499 - accuracy: 0.9 - ETA: 45s - loss: 0.15 - ETA: 43s - loss - ETA: 41s - loss: 0.1502 - accuracy: - ETA: 40s - loss: 0.1504 - accura - ETA: 39s - loss: 0.1504 - accuracy:  - ETA: 39s - ETA: 36s - loss: 0.1500 - accura - ETA: 35s - loss: 0.1500 - accuracy: 0. - ETA: 34s - - ETA: 24s - loss: - ETA: 22s - loss: 0.1496 - accuracy:  - ETA: 21s - loss: 0.1496 - accuracy: 0 - ETA: 21s - loss: 0.1497 -  - E - ETA: 16s - loss: 0.149 - ETA: 14s - loss: 0.1496 - accuracy: 0.94 - ETA: 14s - loss: 0.1496 - accuracy: 0.94 - ETA: 13s - loss: 0.1496 - accuracy: 0 - ETA: 13s - loss: 0.1496 - a - ET - ETA:  - ETA: 3s - los - ETA: 2s - loss: 0.1498 -  - ETA: 2s - loss: 0.1 - ETA: 1s - loss:
# Epoch 33/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1494 - accuracy: 0.9415 - val_loss: 0.1415 - val_accuracy: 0.9448- accuracy: 0.93 - - ETA: 1:59 - loss: 0.1494 - accuracy:  - ETA: 1:58 - loss: 0.149 - ETA: 1:58 - loss: 0.1521 - accuracy:  - ETA: 1:57 - loss: 0.1523 - accura - ETA: 1:57 - loss: 0.1512 - accuracy - ETA: 1:56 - loss: 0.1516 - accuracy: 0.93 - ETA: 1:56 - loss: 0.1511 - accuracy: 0. - ETA: 1:56 - loss: 0.1505  - ETA: 1:55 - loss: - ETA - ETA: 1:52 - loss: 0.1514 - accuracy - ETA: 1:52 - loss: 0.1 - ETA: 1:51 - loss: 0.1518 -  - ETA: 1:50 - loss: 0.1508 - accuracy - ETA: 1:50 - l - ETA: 1:48 - loss: 0.1 - ETA:  - ETA: 1:46 - loss: 0.1508 - accu - ETA: 1:45 - loss: 0.1509 - accuracy:  - ETA: 1:45 - loss: 0 - ETA: 1:42 - loss: - ETA - ETA: 1:39 - loss: 0.1494 - ac - ETA: 1:39 - loss: 0.1492 - accura - ETA: 1:38 - loss: 0.149 - ETA: 1:37 - loss: 0.1 - ETA: 1:36 - loss: 0.1488 - accuracy - ETA: 1:36 - loss: 0.1488 - accuracy: 0.94 - ETA: 1:36 - loss: 0.1489 - ac - ETA: 1:35 - loss: 0.1491 - accuracy:  - ETA: 1:31 - loss: 0.150 - ETA: 1:30 - loss: - ETA - ETA: 1:19 - loss: 0.1501 - ac - ETA: 1:19 - loss: 0.1 - ETA: 1:18 - loss: 0.1497 - accura - - ETA: 1:15 - loss: 0.1 - ETA: 1:15 - loss: 0 - ETA: 1:13 - loss: 0.1495 - accuracy: 0. - ETA: 1:13 - loss: 0.1497 - accu - ETA: 1:13 - ETA: 1:09 - - ETA: 1:06 - loss: 0.1497 - accuracy: 0.94 - ETA: 1:06 - loss: 0.1497 - accuracy:  - ETA: 1:06 - loss: 0.1498 - accu - ETA: 1:05 - loss: 0.1498 - accu - ETA: 1:05 - loss: 0.1498 - accuracy - ETA: 1:02 - loss: 0.1496  - ETA: 1:01 - loss: 0.1496 - ac - ETA: 1:01 - loss: 0.1495 - accuracy: 0.94 - ETA: 1:01 - loss: 0.1496 - accuracy - ETA: 1:00 - loss: 0.1495 -  - ETA: 1:00 - loss: 0.1494  - ETA: 58s - loss: 0.1491 - accuracy: 0.941 - - ETA: 55s - loss: 0.1493 - accur - ETA: 54s - loss: 0.1491 - - ETA: 52s - loss: 0.1492 -  - ETA: 51s - loss: 0.1492 - accu - ETA: 50s - loss: 0.1492 - ac - ETA: 48s - loss: 0.1491 - accuracy: 0.941 - ETA: 48s - loss: 0.1491 - accuracy - ETA: 48s - loss: 0.1490 - accurac - ETA: 47s - lo - ETA: 44s - loss: 0  - ETA: 39s - loss: 0.1486 - accuracy: 0. - ETA: 38s - ETA: 35s - loss: 0.1488 -  - ETA: 34s - loss: 0.1488 - accuracy:  - ETA: 33s - loss: 0.1488 - accuracy: 0. - ETA: 33s - loss: 0.1488 - ac - ETA: 28s - loss - ETA: 26s - loss: 0.1490 - accuracy - ETA: 25s - loss: 0.1489  - ETA: 23s - los - ETA: 21s - loss: 0.1489 - accuracy: 0 - ETA: 20s - loss: 0.1491 - accurac - ETA: 20s - loss: 0.1490 - accuracy: 0. - ETA: 19s - loss: 0.1491 - accuracy: 0.9 - ETA: 19s - loss: 0.1490 - accuracy: 0 - ETA: 19s - loss: 0.1490 - accuracy: 0.941 - ETA: 19s - loss: 0.1490 - accuracy: 0.941 - ETA: 18s - loss: 0.1490 - accuracy - ETA: 18s - loss: 0.1491 - accuracy: 0. - ETA: 17s - loss: 0.1491 - accurac - ETA: 17s - loss: 0.1491 - accuracy: - ETA: 16s - loss: 0.1492 - accuracy: 0.941 - ETA: 16s - loss: 0.1492 - accuracy: 0.941 - ETA: 16s - loss: 0.1492 - accura - ETA: 15s - loss: 0.1491 - accuracy: 0 - ETA: 15s - loss: 0.1492 - accuracy: 0.94 - ETA: 14s - lo - ETA: 12s - loss: 0. - ETA: 10s - loss: 0.1495 - accuracy: 0.941 - ETA: 10s - loss: 0.149 - ETA: 9s - loss: 0 - ETA: 8s - loss: 0.1494 - accuracy - ETA: 7s - loss: 0.1495 -  - ETA: 5s - loss: 0.1496 - accu - ETA: 4s - loss: 0.1497 - accura - ETA: 4s - loss: 0 - ETA: 3s - loss: 0.1 - ETA: 2s - loss: 0 - ETA: 1s - loss: 0.149 - ETA: 0s - loss: 0.1495 - accuracy
# Epoch 34/50
# ...
# Epoch 42/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1467 - accuracy: 0.9425 - val_loss: 0.1464 - val_accuracy: 0.9445 ETA: 2:00 - loss: 0.1443 - accuracy - ETA: 2:00 - loss: 0.1470 - accuracy: 0. - ETA: 1:59 - loss: 0.1483 - accuracy:  - ETA: 1:59 - loss: 0.1506 - accura - ETA: 1:57 - loss: 0.1470 - accuracy: 0.94 - ETA: 1:56 - loss: 0.1475  - ETA: 1:56 - loss: 0.1468  - ETA: 1:55 - loss: 0.1459 - ac - ETA: 1:54 - loss: 0.144 - ETA:  - ETA: 1:38 - loss: 0.1458 - accuracy: 0.94 - ETA: 1:37 - - ETA:  - ETA: 1:32 - loss: 0.1459 - accuracy: 0. - ETA: 1:32 - loss: 0.1 - ETA: 1:31 - loss: 0.1460 - accuracy: 0. - ETA: 1:31 - loss: 0.1459 - ac - ETA: 1:30 - loss: 0 - ETA: 1:27 - loss: 0.1468 - accuracy - ETA: 1:27 - loss: 0.1467 - accu - ETA: 1:27 - loss: 0.1466 - accuracy: 0.94 - ETA: 1:27 - loss: 0.1465 - accuracy: 0.94 - ETA: 1:26 - loss: 0.146 - ETA: 1:26 - loss: 0.1466 - accuracy:  - ETA: 1:25 - loss: 0.1467 -  - ETA: 1:25 - loss: 0.1468 - ac - ETA: 1:24 - loss: 0.1466 - accuracy: 0. - ETA: 1:24 - loss: 0.1466 - accuracy: 0.94 - ETA: 1:24 - loss: 0.1466 - accuracy: 0.94 - - ETA: 1:20 - loss: 0.1471 - accura - E - ETA: 1:17 - loss: 0.1472 - accuracy: 0. - ETA: 1:17 - loss: 0.1472 - ac - ETA: 1:17 - l - ETA: 1:15 - - ETA: 1:12 - loss: 0.146 - ETA: 1:11 - loss: 0.1 - ETA: 1:10 - ETA: 1:09 - loss: 0.1465 - accuracy:  - ETA: 1:08 - loss: 0.1465 - accuracy: 0. - ETA: 1:08 - loss: 0.1465 - accuracy: 0.94 - ETA: 1:08 - loss: 0.1466 - ac - ETA: 1:08 - loss: 0.1465 - accuracy:  - ETA: 1:07 - loss: - ETA: 1:04 - loss: 0.1 - ETA: 1:03 - loss: 0.1470  - ETA: 1:03 - loss: 0.1470 - accuracy:  - ETA: 1:02 - loss: 0.1470 - accu - ETA: 1:02 - los - ETA: 1:00 - los - ETA: 59s - loss: 0.1467 - accur - ETA: 58s - loss: 0.1468 - accuracy - ETA: 57s - loss: 0. - ETA: 55s - loss: 0.1467 - accuracy: 0.94 - ETA: 55s - loss: 0.14 - ETA: 53s - loss: 0 - ETA: 51s - loss: 0.1464 - accuracy: 0.94 - ETA: 51s - loss: 0.1464 - accuracy:  - ETA: 51s - loss: 0.1465 - a - ETA: 49s - loss: 0.1464 - accura - ETA: 48s - loss: 0.1466 - accuracy - ETA: 48s - loss: 0.1467 - accurac - ETA: 47s - loss: 0.1468 - accuracy:  - ETA: 46s - loss: 0.146 - ETA: 45 - ETA: 42s - loss: 0.1465 - accurac - ETA: 4 - ETA: 38s - loss: 0.1470 - accuracy: 0.94 - ETA: 37s - loss: 0.1470 - accurac - ETA: 37s - loss: 0.1471 - accuracy: 0.942 - ETA: 37s - loss: 0.14 - ETA: 35s - loss: 0.1470 - accuracy: 0 - ETA: 34s - loss: 0.1470 - accuracy - ETA - ETA: 30s - loss: 0.1469 - accuracy: 0. - ETA: 30s - loss: 0.1469 - accuracy: - ETA: 29s - loss: 0.1469 - accurac - ETA: 28s - loss: 0.147 - ETA: 27s - loss: 0.1470 - accuracy: 0.942 - ETA - ETA: 23s - loss: 0.1469 - accuracy: 0.942 - ETA: 23s - loss: 0.1469 - accuracy - ETA: 22s - loss: 0.1469 - accuracy: 0.94 - ETA: 22s - loss: 0.1469 - accuracy: 0.942 - ETA: 22s - loss: 0.1469 - accuracy: - ETA: 22s - loss: 0.1470 - accuracy: 0.94 - ETA: 21s - loss: 0.1470 - accuracy: 0.942 - ETA: 21s - loss: 0.1 - ETA: 19s - loss: 0.1470 - accuracy: 0.94 - ETA: 19s - loss: 0.1470 - accuracy: - ETA:  - ETA: 11s - loss: 0.1467 - accu - ETA: 10s - loss: 0.1466 - accuracy - ETA: 10s - loss: 0.1467 - accurac - ETA: 9s - loss: 0.1467 - accuracy:  - - ETA: 1s - loss: 0.1466  - ETA: 1s - loss: 0.1466 - accuracy: 0.94 - ETA: 0s - loss: 0.1
# Epoch 43/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1461 - accuracy: 0.9428 - val_loss: 0.1418 - val_accuracy: 0.9459TA: 2:01 - loss: - ETA: 1:59 - loss: 0.1398 -  - ETA: 1:59 - l - ETA - ETA: 1:56 - loss: 0.1426 -  - ETA: 1:55 - loss: 0.142 - ETA: 1:54 - loss: 0.1439 - accuracy:  - ETA: 1:54 - loss: 0.1438 - accuracy: 0.94 - ETA: 1:53 - loss: 0.1441 - accuracy: 0. - ETA: 1:53 - los - ETA: 1:52 - loss: 0 - ETA: 1:51 - loss: 0.1448 - accuracy - ETA: 1:50 - loss: 0.1445 - accura - ETA: 1:50 - loss: 0.1441 - ac - - ETA: 1:47 - l - ETA: 1:46 - loss: 0 - ETA: 1:45 - loss: 0.1 - ETA: 1:44 - loss: 0.1445 - ac - ETA: 1:43 - ETA: 1:42 - loss: - ETA: 1:41 - loss: 0.1450 - accuracy: 0. - ETA: 1:41 - loss: 0.145 - ETA:  - ETA: 1:38 - loss: 0.1457 - accuracy: 0. - ETA: 1:38 - loss: 0.1459 - ac - ETA: 1:37 - loss: 0.1460 - accuracy: 0.94 - ETA: 1:37 - loss: 0.146 - ETA: 1:36 - loss: 0.1454 -  - ETA: 1:36 - loss: 0 - ETA: 1:35 - loss: 0.1450 - accu - ETA: 1:34 - ETA: 1:33 - loss: 0.1458  - ETA: 1:32 - loss: 0.145 - ETA - ETA: 1:29 - loss: 0.1458 - accura - ETA: 1:29 - loss: 0.145 - ETA: 1:28 - loss: 0.1457 - accuracy:  - ETA: 1:28 - loss: 0.1457 -  - ETA: 1:25 - loss: 0.1459 - accuracy: 0.94 - ETA: 1:25 - loss: 0.1459  - ETA: 1:24 - loss: 0.1459 - accuracy: 0.94 - ETA: 1:24 - loss: 0.1459 - accuracy:  - E - ETA: 1:20 - loss: 0.1465 - accuracy: 0. - ETA: 1:20 - los - ETA: 1:19 - ETA: 1:17 - loss: 0.1462 - accuracy - ETA: 1:15 - loss: 0.1462 - accuracy: 0.94 - ETA: 1:15 - loss: 0.1461 - ac - ETA: 1:14 - loss: - ETA: 1:13 - loss: - ETA: 1:12 - loss: 0.1464 - accuracy: 0.94 - ETA: 1:12 - - ETA: 1:11 - l - ETA: 1:05 - loss: - ETA: 1:04 - loss: 0 - ETA - ETA: 59s - loss: 0.1462 - accura - ETA: 58s - loss: 0.14 - ETA: 56s - loss: 0.1463 - accuracy: 0. - ETA: 56s  - ETA: 53s - loss: 0.1463 - accuracy: 0.942 - ETA: 53s - loss: 0.1463 - accura - ETA: 52s - loss: 0.1466 - ac - ETA: 51s - loss: 0.146 - ETA: 49s - loss: 0.1467 - accuracy: - ETA: 49s - loss: 0.1467 - ETA: 47s - loss: 0.1467 - accuracy - ETA: 46s - loss: 0.1467 - accuracy: 0.942 - ETA: 46s - loss:  - ETA: 44s - loss: 0.1464 - accuracy: 0.942 - ETA: 44s - loss: 0.1465 - accuracy: - ETA: 43s - loss: 0.1466 - accuracy: 0.942 - ETA: 43s - loss: 0.1466 - accuracy: 0.942 - ETA: 43s - loss: - ETA: 41s - loss: 0.1468  - ETA: 39s - loss: 0.1467 - accuracy: 0. - ETA: 39s - loss: 0.1467 - accur - ETA: 38s - loss: 0.1468 - accuracy: - ETA: 37s - loss: 0.1468 - accura - ETA: 37s - loss: 0.1467 - accuracy: 0 - ETA: 36s - loss: 0.1467 - - ETA: 35s - loss: 0.1467 - accuracy: 0. - ETA: 34s - loss: 0.1467 - ac - ETA: 33s - loss: 0.1468 - accuracy: 0.942 - ETA: 33s - loss: 0.1468 - accuracy: 0. - ETA: 33s - loss: 0.1467 - accuracy: 0 - ETA: 32s - loss: 0.1466 - accuracy: - ETA: 31s - loss: 0.1465 - accuracy:  - ETA: 31s - loss: 0.1464 - accuracy: 0 - ETA: 31s - loss: 0.1464 - accuracy:  - ETA: 30s - loss: 0.14 - ETA: 28s - loss: 0.1463 - accuracy: 0.942 - ETA: 28s - loss: 0.1463 - ac - ETA: 27s - loss: 0.1462 - accuracy: - ETA: 26s - loss: 0.1461 - acc - ETA: 25s - loss: 0.1460 - accuracy: 0.94 - ETA: 25s - loss: 0.1460 - ETA: 23s - loss: 0.1460 - accuracy: 0.9 - ETA: 23s - loss: 0.1461 - accuracy: 0.942 - ETA: 23s - loss: 0. - ETA: 21s - loss: 0.1463 - accuracy: - ETA: 20s - loss: 0.1463 - accuracy: 0.9 - ETA: 20s - loss: 0.1463 - accura - ETA: 19s - loss: 0.1463 - accu - ETA: 18s - loss: 0.1463 - accur - ETA: 17s - loss: 0.1462 - accuracy: - ETA: 17s - loss: 0.1461 - accuracy: - ETA: 16s - loss: 0.1461 - accuracy: 0.942 - ETA: 16s - loss: 0.1461 - - ETA: 14s - loss: 0.1459 - accuracy: 0.9 - ETA: 14s - loss: 0.1459 - accur - ETA: 13s - loss: 0.1458 - ac - ETA:  - ETA: 7s - loss: 0.1460 - accuracy: 0. - ETA: 7s - loss: 0.1460 - accuracy: 0.94 - ETA: 7s - l - ETA: 6s - - ETA: 4s - loss: 0.1460 - accu - ETA: 0s - loss: 0.1461 - accu
# Epoch 44/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1459 - accuracy: 0.9429 - val_loss: 0.1421 - val_accuracy: 0.9456: 2:03 - ETA: 1:58 - - ETA: 1:55 - loss: 0.142 - ETA: 1:54 - loss: 0.1418 - accuracy: 0.94 - ETA: 1:54 - loss: 0.141 - ETA: 1:54 - los - ETA: 1:52 - loss: 0.1439 - accuracy: 0.94 - ETA: 1:52 - loss: 0.1440 - accuracy: 0.94 - ETA: 1:52 - loss: - ETA: 1:45 - loss: 0.1427 - ac - ETA: 1:42 - ETA: 1:40 - ETA: 1:39 - loss: 0.142 - ETA: 1:38 - loss: 0.1423 - accuracy:  - ETA: 1:38 - loss: 0.1420 - accuracy:  - ETA: 1:37 - loss: 0.1421  - ETA: 1:37 - loss: 0.1418 - accuracy:  - ETA: 1:36 - loss: 0.1417 - ac - ETA: 1:34 - loss: 0.1421  - ETA: 1:29 - loss: 0.1430 - accuracy:  - ETA: 1:29 - loss: 0.143 - ETA: 1:28 - loss: 0.1433 - ac - ETA: 1:27 - loss: 0.1434 -  - ETA: 1:26 - loss: 0.1437 - accuracy:  - ETA: 1: - E - ETA: 1:22 - loss: 0.1437  - ETA: 1:22 - loss: - ETA: 1:21 - loss: 0.1441 -  - ETA: 1:20 - loss: 0.1443 - accuracy: 0. - ETA: 1:20 - loss: 0.1445 - accuracy:  - E - ETA - ETA: 1:14 - loss: 0.144 - ETA: 1:13 - loss: 0 - ETA: 1:12 - loss: 0.1449 - accura - ETA: 1: - ETA: 1:10 - loss: 0.145 - ETA: 1:07 - loss: - ETA: 1:06 - loss: 0.1452 - accuracy: 0.94 - ETA: 1:06 - loss: 0.1452  - ETA: 1:05 - loss: - ETA: 1:04 - loss: 0.1452 - accuracy:  - ETA: 1:04 - loss: 0.1 - ETA: 1:03 - loss: 0.1453 - accuracy:  - ETA: 1:03 - l - ETA: 1:01 - loss: 0.1452 - accura - ETA: 1:01 - ETA: 59s - loss: 0.1452 - accuracy: 0.943 - ETA: 59s - loss: 0.1452 - accuracy: 0.94 - ETA: 59s - loss: 0.1452 - accuracy: 0.94 - ETA: 59s - - ETA: 56s - loss: 0.1452 - accuracy: 0.94 - ETA: 56s - loss: 0.1452 - accur - ETA: -  - ETA: 44s - loss: 0.1450 - accuracy: 0.94 - ETA: 44s - loss: 0.1450 - accurac - ETA: 43s - loss: 0.1449 - accuracy: 0.943 - ETA: 43s - loss: 0.1449 - accura - ETA: 42s - loss: 0.1451 - ac - ETA: 41s - loss: 0.1451 - accuracy: 0.94 - ETA: 41s - loss: 0.1451 - accuracy: 0.943 - ETA: 41s - loss: 0.1450 - accura - ETA: 40s - loss: 0.1451  - ETA: 38s - loss: 0.1450 - accu - ETA: 37s - loss: - ETA: 35s - loss: 0.1453 - accuracy - ETA: 34s - loss: 0.1452 - accuracy - ETA: 34s - loss: 0.1451 - accurac - ETA: 33s - lo - ETA: 30s - loss: 0.1456 - a - ETA: 29s - loss: 0.14 - ETA: 23s - loss: 0.1456 - accuracy: 0.94 - ETA: 23s - loss: - ETA: 21s - loss: 0.1456 - accura - ETA: 20s - loss: 0.1455 - accuracy: 0.943 - ETA: 20s - loss: 0.1456 - accur - ETA: 19s - loss: 0.1457 - accuracy: 0 - ETA: 18s - loss: 0.1458 - - ETA: 17s - loss: 0.1457 - accuracy: - ETA: 1 - ETA: 13s - loss: 0.1459 - accuracy: 0.9 - ETA: 13 -  - ETA: 8s - loss: 0.1459 - accura - ETA: 7s - loss: 0.1459 - accuracy:  - ETA: 7s - los - ETA: 6s - loss: 0.1459 - accuracy: 0.94 - ETA: 4s - loss: 0.1460  - ETA: 1s - loss: 0.1459 - accuracy: 0.94 - ETA: 1s - loss: 0.1459 - accuracy: 0.94 - ETA
# Epoch 45/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1455 - accuracy: 0.9429 - val_loss: 0.1431 - val_accuracy: 0.942801 - loss: 0.1370 -  - ETA: 1:58 - loss: - ETA: 1:57 - loss: 0.1416 - accu - ETA:  - ETA: 1:55 - loss: 0.1418 - accuracy: 0. - E - ETA: 1:50 - loss: 0.1426 - ac - ETA: 1:48 - loss: 0.1435 - accuracy:  - ETA: 1:45 - loss: 0.1443 - accuracy: 0.94 - ETA: 1:45 - - ETA: 1:44 - loss: 0.1454 -  - ETA: 1:43 - ETA: 1:42 - loss: 0.1452 - accuracy:  - ETA: 1:41 - l - ETA: 1:40 - loss: 0.1446 -  - ETA: 1:40 - loss: 0.1 - E - ETA: 1:35 - loss: 0.1435 - accuracy:  - ETA: 1:33 - loss: 0 - ETA: 1:32 - loss: 0.1441 - accuracy: 0.94 - ETA: 1:31 - loss: 0.1442 -  - E - - ETA: 1: - ETA: 1:15 - loss: 0.1455 - accura - ETA: 1:15 - l - ETA: 1:14 - loss: 0.1455 - accuracy: 0.94 - ETA: 1:14 - loss: 0.1455 - ac - ETA: 1:13 - loss: 0.1452 - accuracy - ETA: 1: - ETA: 1:05 - loss: 0.1453 - ac - ETA: 1:00 - loss: 0.1458 - accura - ETA: 1:00 - loss: 0.14 - ETA: 59s - loss: 0.1459 -  - ETA: 57s - loss: 0.1458 - accuracy - ETA: 56s - loss: 0.1457 - accuracy: 0.94 - ETA: 56s - loss: 0.1457 - accura - ET - ETA: 52s - loss - ETA: 50s - loss: 0.1456 - accurac - ETA: 49s - loss: 0.1456 -  - ETA: 47s - loss: 0.1456 - accuracy - ETA: 47s - loss: 0.1457 - accuracy - ETA: 46s - loss: 0.1456 -  - ETA: 45s - loss: 0.145 - ETA: - ETA: 40s - loss: 0.1458 - accuracy: 0.94 - ETA: 39s - loss: 0.1459 - accurac - ETA: 35s - loss: 0.1 - ETA: 33s - loss: 0.1458 - accuracy: 0 - ETA: 32s - loss: 0.1 - ETA: 30s - loss: 0.1459 - accurac - ETA: 30s - los - ETA: 27s - loss: 0.1457 - accuracy: 0.942 - ETA: 27s - l - ETA: 25s - loss: 0.1460  - ETA: 23s - lo - ETA: 20s - loss: 0.1459 - accuracy: 0. - ETA: 20s - loss: 0.1460 - accuracy: 0.94 - ETA: 20s - loss: 0.1460 - accuracy: 0.94 - ETA: 20s - loss: 0.1460 - accuracy: 0.942 - ETA: 20s - loss: 0.1460 - accuracy: 0.942 - ETA: 20s - loss: 0.146 - ETA: 18s - loss: 0.1459 - a - ETA: 17s - loss: 0.1461 - accuracy: 0.942 - ETA: 17s - loss: 0.1461 - accuracy: - ETA: 16s - loss: 0.1459 - acc - ETA: 15s - loss: 0.1459 - accur - ETA: 14s - loss: 0.1458 - accuracy: 0.94 - ETA: 14s - loss: 0.1458 - accuracy: 0.942 - ETA: 14s - loss: 0.1458 - accurac - ETA: 13s - loss: 0.1458 - accuracy: 0 - ETA: 12s - loss: 0.1458 - accuracy:  - ETA: 12s - loss: 0.1458 - accuracy:  - ETA: 9s - loss: 0.1457 - accu - ETA: 8s - loss: 0.1457 - accuracy - ETA: 8s - loss: 0.145 - ETA: 7s - loss: 0.1457 - accuracy: 0. - ETA: 7s - loss: 0.1457 - ac - ETA: 6s - los - - ETA: 1s - loss: 0.1457 - accuracy - ETA: 1s - loss: 0.1457 - accu - ETA: 0s - loss: 0.1456 - ac
# Epoch 46/50
# 82800/82800 [==============================] - 143s 2ms/sample - loss: 0.1454 - accuracy: 0.9429 - val_loss: 0.1423 - val_accuracy: 0.9446 loss: 0.1526 - accuracy: 0.93 - ETA: 2:01 - loss: 0.1512 : 4s - loss: 0.1455 - accura - ETA: 3s - loss: 0.145 - ETA: 2s - loss: 0.1
# Epoch 48/50
# 82800/82800 [==============================] - 143s 2ms/sample - : 0.1447 - accuracy:  - ETA: 1s - loss: 0.1447 - accuracy:  - ETA: 1s - loss: 0.144 - ETA: 0s - loss: 0.1447 - accura
# [150.4650754928589, 145.48278164863586, 146.7353699207306, 146.60711479187012, 147.79115891456604, 144.65567183494568, 146.43800950050354, 151.83586764335632, 143.90190887451172, 143.96784281730652, 143.1687467098236, 143.15118145942688, 143.19784903526306, 143.0997874736786, 143.19131803512573, 143.27820873260498, 143.13467955589294, 143.10376691818237, 143.17612743377686, 143.1806468963623, 143.16500806808472, 143.1425952911377, 143.77704215049744, 143.9850935935974, 144.16722106933594, 142.68158197402954, 142.58791851997375, 142.71923112869263, 142.63689637184143, 142.74874019622803, 142.78657269477844, 142.90986132621765, 142.82913637161255, 142.6791386604309, 142.588045835495, 142.7462420463562, 142.95446729660034, 142.50835156440735, 142.70294952392578, 142.84971690177917, 142.85923099517822, 142.88721656799316, 142.76821088790894, 142.80229234695435, 142.7732253074646, 142.76199293136597, 142.8227982521057, 142.95871949195862, 142.89908576011658, 142.69546127319336]

# %%
# plot train and validation loss 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show(); plt.close()

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
#load for validation different directrory different ids
coco_instances = COCO(os.path.join(dataDir,r"annotations\instances_" + val_data_name + ".json"))

# in the .getCatIds(catNms=[list of all ids we want to filter from the data]);
catIds = coco_instances.getCatIds(catNms=categories_names);

# get all the image id for all images here its for the validation
all_imgIds = coco_instances.getImgIds();

# get all the image id for all images based on the filter
imgIds = coco_instances.getImgIds(catIds=catIds);

img_list = []
mask_list = []

for cnt, imgID in enumerate(all_imgIds):
    I = cv2.imread(os.path.join(dataDir, val_data_name +r"//" +str(imgID).zfill(12) + ".jpg"),rgb_on)
    I = cv2.resize(I, dsize=(img_width, img_height), interpolation=cv2.INTER_CUBIC)
    img_list.append(I)
    
    if (imgID in imgIds):
        annIds = coco_instances.getAnnIds(imgIds=imgID, catIds=catIds, iscrowd=None)
        anns = coco_instances.loadAnns(annIds)
        img_data = coco_instances.loadImgs(imgID)[0]
        anns_img = np.zeros((img_height, img_width),)
        for ann in anns:
            mask_res = cv2.resize(coco_instances.annToMask(ann), (img_height, img_width), interpolation = cv2.INTER_AREA )
            anns_img = np.maximum(anns_img, mask_res*(catIds.index((ann['category_id']))+1))
        
        #mask = cv2.resize(anns_img, dsize=(img_width, img_height), interpolation=cv2.INTER_CUBIC)    
        #save mask to disk
        #cv2.imwrite(r"E:\Documents\Study\Deep Learning\Project\TestMASKS\\" +str(imgID).zfill(12) + ".png" , mask)
    else:
        anns_img = np.zeros((img_height, img_width),)
        
    mask_list.append(anns_img)
    
    if (cnt+1 == max_cnt_debug_test):
        break
    
#y_train = read_data(r'E:\Documents\Study\Deep Learning\Project\MASKS')
#y_train = (to_categorical(y_train)).astype('float')

y_test = np.asarray(mask_list)
#y_test = (np.expand_dims(y_test, axis=3)).astype('float')
y_test = (to_categorical(y_test, num_classes=2, dtype='float32')).astype('float')


x_test = np.asarray(img_list).astype('float')

if (rgb_on == 0):
    x_test = (np.expand_dims(x_test, axis=3)).astype('float')

print('x_test shape:', x_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# loading annotations into memory...
# Done (t=1.52s)
# creating index...
# index created!
# x_test shape: (5000, 64, 64, 3)
# y_test shape: (5000, 64, 64, 2)

# %%
plt.subplot(3,3,1)
plt.imshow(np.squeeze(x_test[0,:,:].astype('uint8')))
plt.axis('off')

plt.subplot(3,3,2)
plt.imshow(np.squeeze(x_test[1,:,:].astype('uint')))
plt.axis('off')

plt.subplot(3,3,3)
plt.imshow(np.squeeze(x_test[2,:,:].astype('uint')))
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
#plt.hist((coco_instances.annToMask(ann)*49).ravel(),256, [0,255]);
#plt.hist(mask_list[0].ravel(),256, [0,255]);
#plt.imshow(mask_list[0])

# %%
y_pred = loaded_model.predict(x_test)

# %%
y_pred = model.predict(x_test)
test_loss, test_acc = model.evaluate(x_test, y_test)

# Print results
print('test loss:', test_loss)
print('test accuracy:', test_acc)
# Out:
# 5000/1 [==============================================================================================================================================================================] - 3s 622us/sample - loss: 0.2073 - accuracy: 0.9441
# test loss: 0.14534304783344268
# test accuracy: 0.9440575

# %%
# #Visialize the source image
# img = cv2.imread(os.path.join(dataDir, data_name +r"//" +str(imgIds[0]).zfill(12) + ".jpg"),0)
# plt.imshow(img)

# %%
#Visialize the resized image
# visualize the predicted resaults vs the real resaults
img_idx = 3

if (rgb_on == 0):
    plt.imshow((x_test[img_idx,:,:,0]).astype('uint8'))
else:
    plt.imshow((x_test[img_idx,:,:]).astype('uint8'))
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
# visualize the predicted resaults vs the real resaults

plt.subplot(3,2,1)
plt.imshow((y_pred[img_idx,:,:,0]*255).astype('uint8'))
plt.axis('off')

plt.subplot(3,2,2)
plt.imshow((y_pred[img_idx,:,:,1]*255).astype('uint8'))
plt.axis('off')

plt.subplot(3,2,3)
plt.imshow((y_test[img_idx,:,:,0]*255).astype('uint8'))
plt.axis('off')

plt.subplot(3,2,4)
plt.imshow((y_test[img_idx,:,:,1]*255).astype('uint8'))
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
# auc roc for the good model the fist class
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# Plot linewidth.
lw = 2

# Compute ROC curve and ROC area for each class
fpr, tpr, _ = roc_curve(y_test[:,:,:,0].flatten(), y_pred[:,:,:,0].flatten())
roc_auc = auc(fpr, tpr)


plt.plot(fpr, tpr, color='green', lw=lw,label='ROC curve of class (AUC = {0})' ''.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic COCO person recognition')
plt.legend(loc="lower right")
plt.show()

# %%
# load 12 layers from the model
layer_outputs = [layer.output for layer in loaded_model.layers] # Extracts the outputs of the top 12 layers
activation_model = Model(inputs=loaded_model.input, outputs=layer_outputs) # Creates a model that will return these outputs, given the model input

# %%
activations = activation_model.predict(x_test) # Returns a list of five Numpy arrays: one array per layer activation
img_idx = 2
plt.matshow(x_test[img_idx, :, :].astype('uint8'))
plt.axis('off')
for idx, act in enumerate(activations):
    plt.subplot(8,4,idx+1)
    plt.imshow(act[img_idx, :, :, 0], cmap='viridis')
    plt.axis('off')
